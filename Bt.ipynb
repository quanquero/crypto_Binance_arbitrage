# %% [markdown]
# # Методы

# %% [markdown]
# ## Keys

# %%
#1 кошелек, откуда переливаем

b1_API_KEY='';  N=42; percent=50
b1_API_SECRET='' #28.01.23


# кошелек, куда переливаем
    # Нияз B
b2_API_KEY=''
b2_API_SECRET='' 

# загрузка функций
# %run fn.ipynb

# %%
#3 подготовка параметров для торговли  
min_spread_in_percent = 0.4

b = 'QKC'; # 2/10
q = 'BUSD'; u = 'BUSD'



#------------------
Work_usd  = 90 # количество USD для работы
usd_min   = 25
kb = 0.98
#------------------
find_pairs(b, q, u)
coin_bunch = 2
if q == u : busd_busd = True
else      : busd_busd = False
o1={}; o2={}
client_report = ''
isWriteToFile = False
# Out:
# base_quote: QKCBUSD
# base_usd: QKCBUSD True
# usd_quote: BUSDBUSD False

# %%
#4 START

isWriteToFile = True
if isWriteToFile : f = createFile('rep\B1')


BS_async = True
SB_async = True
time_b2_b1 = 0.5

time_wait_spread = 3 #sek
eat_vol = 0.06


cancel_orders(bot2)
get_new_Work_usd()
busd_to_bnb()

#after_sell()

# Если начинать с продажи
#await _try_sell_buy()  if SB_async else try_sell_buy()


#global client_report
step = 1
while 1 :
  print('\n--------------------------------------------------------------------------------')
  print(f'шаг {step}')
  client_report = client_report + f'шаг {step}' + '\n'
  print('\n------------BUY - SELL')

  #is_async if   await try_buy_sell() else try_buy_sell()
  await _try_buy_sell()  if BS_async else try_buy_sell()

  if step % 2 == 1 :
    print('\n------------BUSD_TO_BNB')
    busd_to_bnb()  #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
  if step % 8 == 1 :
    print('\n------------WORK_USD')
    get_new_Work_usd()
  print('\n------------SELL - BUY')

    
  await _try_sell_buy()  if SB_async else try_sell_buy()

  t = random.random() *35 + 5
  print('sleep: ', t)
  time.sleep( t )
  step = step + 1
# Out:
# b1 b:11269.0(123) q:11.48(11)   bq:134.46  B:0.059   <>:134.46
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.4  B:0.037   <>:3985.40
# New W_usd: 121.02
# b1 b:11269.0(123) q:11.48(11)   bq:134.46  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.4  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# --------------------------------------------------------------------------------
# шаг 1
#
# ------------BUY - SELL
# b1 b:11269.0(123) q:11.48(11)   bq:134.46  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.4  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.01   ping: 44   bid: 0.010914   ask: 0.010915
# QKCBUSD . спрэд: 0.09   ping: 69   bid: 0.010914   ask: 0.010924
# QKCBUSD . спрэд: 0.19   ping: 31   bid: 0.010902   ask: 0.010923
# QKCBUSD . спрэд: 0.01   ping: 31   bid: 0.010918   ask: 0.010919
# QKCBUSD . спрэд: 0.05   ping: 63   bid: 0.010918   ask: 0.010924
# QKCBUSD . спрэд: 0.14   ping: 49   bid: 0.010902   ask: 0.010917
# QKCBUSD . спрэд: 0.01   ping: 31   bid: 0.010916   ask: 0.010917
# QKCBUSD . спрэд: 0.07   ping: 49   bid: 0.010916   ask: 0.010924
# QKCBUSD . спрэд: 0.01   ping: 35   bid: 0.010923   ask: 0.010924
# QKCBUSD . спрэд: 0.19   ping: 47   bid: 0.010902   ask: 0.010923
# QKCBUSD . спрэд: 0.16   ping: 78   bid: 0.010899   ask: 0.010916
# QKCBUSD . спрэд: 0.17   ping: 48   bid: 0.010897   ask: 0.010916
# QKCBUSD . спрэд: 0.23   ping: 39   bid: 0.010891   ask: 0.010916
# QKCBUSD . спрэд: 0.49   ping: 49   bid: 0.0109   ask: 0.010954
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:237.0(3) q:131.30(131)   bq:133.88  B:0.059   <>:0.01
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.25  B:0.037   <>:0.33
#
# ------------BUSD_TO_BNB
# b1 b:237.0(3) q:131.30(131)   bq:133.88  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.25  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------WORK_USD
# b1 b:237.0(3) q:131.30(131)   bq:133.88  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.25  B:0.037   <>:0.00
# New W_usd: 120.49
#
# ------------SELL - BUY
# b1 b:237.0(3) q:131.30(131)   bq:133.88  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.25  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.010952 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# sell_buy() False
#
# b1 b:10785.0(118) q:15.78(16)   bq:133.45  B:0.059   <>:-0.43
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.37  B:0.037   <>:0.12
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:10785.0(118) q:15.78(16)   bq:133.45  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.37  B:0.037   <>:0.00
# sleep:  38.18781245932467
#
# --------------------------------------------------------------------------------
# шаг 2
#
# ------------BUY - SELL
# b1 b:10785.0(118) q:15.78(16)   bq:133.92  B:0.059   <>:0.47
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.84  B:0.037   <>:0.47
# QKCBUSD . спрэд: 0.01   ping: 75   bid: 0.010955   ask: 0.010956
# QKCBUSD . спрэд: 0.12   ping: 63   bid: 0.010955   ask: 0.010968
# QKCBUSD . спрэд: 0.3   ping: 64   bid: 0.010955   ask: 0.010988
# QKCBUSD . спрэд: 0.33   ping: 44   bid: 0.010915   ask: 0.010951
# QKCBUSD . спрэд: 0.32   ping: 48   bid: 0.010915   ask: 0.01095
# QKCBUSD . спрэд: 0.44   ping: 62   bid: 0.010902   ask: 0.01095
# b2 BUY  QKCBUSD price_dwn: 0.010903 quantity: 10558
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  10558
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10558 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:227.0(2) q:15.78(16)   bq:18.25  B:0.059   <>:-115.67
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.27  B:0.037   <>:-0.57
# QKCBUSD . спрэд: 0.01   ping: 38   bid: 0.010902   ask: 0.010903
# QKCBUSD . спрэд: 0.02   ping: 39   bid: 0.010901   ask: 0.010903
# QKCBUSD . спрэд: 0.03   ping: 61   bid: 0.010898   ask: 0.010901
# QKCBUSD . спрэд: 0.01   ping: 64   bid: 0.010897   ask: 0.010898
# QKCBUSD . спрэд: 0.06   ping: 41   bid: 0.010891   ask: 0.010898
# QKCBUSD . спрэд: 0.01   ping: 31   bid: 0.010897   ask: 0.010898
# QKCBUSD . спрэд: 0.06   ping: 52   bid: 0.010897   ask: 0.010903
# QKCBUSD . спрэд: 0.37   ping: 57   bid: 0.010909   ask: 0.010949
# QKCBUSD . спрэд: 0.43   ping: 44   bid: 0.010898   ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:130.89(131)   bq:133.36  B:0.059   <>:115.11
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:-0.04
#
# ------------SELL - BUY
# b1 b:227.0(2) q:130.89(131)   bq:133.36  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.010943 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# sell_buy() False
#
# b1 b:10775.0(118) q:15.46(15)   bq:133.38  B:0.059   <>:0.02
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.72  B:0.037   <>:0.49
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:10775.0(118) q:15.46(15)   bq:133.38  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.72  B:0.037   <>:0.00
# sleep:  8.634208893851998
#
# --------------------------------------------------------------------------------
# шаг 3
#
# ------------BUY - SELL
# b1 b:10775.0(118) q:15.46(15)   bq:133.38  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.72  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.03   ping: 43   bid: 0.010944   ask: 0.010947
# QKCBUSD . спрэд: 0.08   ping: 43   bid: 0.010944   ask: 0.010953
# QKCBUSD . спрэд: 0.37   ping: 46   bid: 0.01091   ask: 0.010951
# QKCBUSD . спрэд: 0.38   ping: 53   bid: 0.01091   ask: 0.010952
# QKCBUSD . спрэд: 0.49   ping: 33   bid: 0.01091   ask: 0.010964
# b2 BUY  QKCBUSD price_dwn: 0.010911 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  10548
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:227.0(2) q:15.46(15)   bq:17.93  B:0.059   <>:-115.45
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.36  B:0.037   <>:-0.36
# QKCBUSD . спрэд: 0.01   ping: 47   bid: 0.01091   ask: 0.010911
# QKCBUSD . спрэд: 0.16   ping: 56   bid: 0.010944   ask: 0.010962
# QKCBUSD . спрэд: 0.47   ping: 63   bid: 0.010911   ask: 0.010962
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:130.55(131)   bq:133.02  B:0.059   <>:115.09
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.37  B:0.037   <>:0.01
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:130.55(131)   bq:133.02  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.37  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:130.55(131)   bq:133.02  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.37  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.01096 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# sell_buy() False
#
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:-115.59
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.52
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.00
# b1 base меньше рабочей суммы
# sleep:  17.520998620017497
# --------------------------------------------------------------------------------
# шаг 4
#
# ------------BUY - SELL
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.9  B:0.037   <>:0.01
# QKCBUSD . спрэд: 0.04   ping: 63   bid: 0.010961   ask: 0.010965
# QKCBUSD . спрэд: 0.07   ping: 31   bid: 0.01096   ask: 0.010968
# QKCBUSD . спрэд: 0.06   ping: 53   bid: 0.010961   ask: 0.010968
# QKCBUSD . спрэд: 0.49   ping: 47   bid: 0.01096   ask: 0.011014
# QKCBUSD . спрэд: 0.09   ping: 35   bid: 0.01096   ask: 0.01097
# QKCBUSD . спрэд: 0.08   ping: 38   bid: 0.010961   ask: 0.01097
# QKCBUSD . спрэд: 0.48   ping: 31   bid: 0.01096   ask: 0.011013
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:-0.01
# b1 quote меньше рабочей суммы
#
# ------------SELL - BUY
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.00
# b1 base меньше рабочей суммы
# sleep:  36.37116567579763
#
# --------------------------------------------------------------------------------
# шаг 5
#
# ------------BUY - SELL
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.43   ping: 35   bid: 0.01096   ask: 0.011007
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.00
# b1 quote меньше рабочей суммы
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:14.95(15)   bq:17.43  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.89  B:0.037   <>:0.00
# b1 base меньше рабочей суммы
# sleep:  20.544715140192867
#
# --------------------------------------------------------------------------------
# шаг 6
#
# ------------BUY - SELL
# b1 b:10775.0(118) q:14.95(15)   bq:132.64  B:0.059   <>:115.21
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.5  B:0.037   <>:-0.39
# QKCBUSD . спрэд: 0.75   ping: 48   bid: 0.010923   ask: 0.011006
# b2 BUY  QKCBUSD price_dwn: 0.010924 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  10548
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:227.0(2) q:130.17(130)   bq:132.65  B:0.059   <>:0.01
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.53  B:0.037   <>:0.03
# QKCBUSD . спрэд: 0.73   ping: 40   bid: 0.010926   ask: 0.011006
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q
B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.19  B:0.037   <>:0.00
# b1 base меньше рабочей суммы
# sleep:  17.775504485802234
#
# --------------------------------------------------------------------------------
# шаг 9
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:0.01
# QKCBUSD . спрэд: 0.39   ping: 48   bid: 0.010896   ask: 0.010939
# QKCBUSD . спрэд: 0.36   ping: 30   bid: 0.010897   ask: 0.010936
# QKCBUSD . спрэд: 0.34   ping: 34   bid: 0.010898   ask: 0.010935
# QKCBUSD . спрэд: 0.36   ping: 62   bid: 0.010896   ask: 0.010935
# QKCBUSD . спрэд: 0.4   ping: 42   bid: 0.010891   ask: 0.010935
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.15  B:0.037   <>:-0.05
# b1 quote меньше рабочей суммы
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.17  B:0.037   <>:0.02
# b1 BNB ok
# b2 BNB ok
#
# ------------WORK_USD
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.18  B:0.037   <>:0.01
# New W_usd: 14.33
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.18  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.18  B:0.037   <>:0.00
# sleep:  8.542583723514896
#
# --------------------------------------------------------------------------------
# шаг 10
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.18  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.37   ping: 36   bid: 0.010894   ask: 0.010934
# QKCBUSD . спрэд: 0.33   ping: 48   bid: 0.010898   ask: 0.010934
# QKCBUSD . спрэд: 0.42   ping: 47   bid: 0.010899   ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:0.06
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:0.00
# sleep:  35.18672077583142
#
# --------------------------------------------------------------------------------
# шаг 11
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:-0.02
# QKCBUSD . спрэд: 0.44   ping: 66   bid: 0.010897   ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# sleep:  27.330737174972842
#
# --------------------------------------------------------------------------------
# шаг 12
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.41   ping: 78   bid: 0.010897   ask: 0.010942
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# sleep:  11.169645745850346
#
# --------------------------------------------------------------------------------
# шаг 13
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.39   ping: 64   bid: 0.010897   ask: 0.01094
# QKCBUSD . спрэд: 0.36   ping: 62   bid: 0.010897   ask: 0.010936
# QKCBUSD . спрэд: 0.35   ping: 40   bid: 0.010897   ask: 0.010935
# QKCBUSD . спрэд: 0.33   ping: 43   bid: 0.010897   ask: 0.010933
# QKCBUSD . спрэд: 0.32   ping: 56   bid: 0.010897   ask: 0.010932
# QKCBUSD . спрэд: 0.3   ping: 39   bid: 0.010897   ask: 0.01093
# QKCBUSD . спрэд: 0.29   ping: 67   bid: 0.010897   ask: 0.010929
# QKCBUSD . спрэд: 0.27   ping: 50   bid: 0.010897   ask: 0.010927
# QKCBUSD . спрэд: 0.26   ping: 55   bid: 0.010897   ask: 0.010925
# QKCBUSD . спрэд: 0.22   ping: 60   bid: 0.0109   ask: 0.010924
# QKCBUSD . спрэд: 0.2   ping: 41   bid: 0.0109   ask: 0.010922
# QKCBUSD . спрэд: 0.19   ping: 38   bid: 0.0109   ask: 0.010921
# QKCBUSD . спрэд: 0.17   ping: 28   bid: 0.0109   ask: 0.010919
# QKCBUSD . спрэд: 0.15   ping: 45   bid: 0.010901   ask: 0.010917
# QKCBUSD . спрэд: 0.39   ping: 46   bid: 0.010901   ask: 0.010944
# QKCBUSD . спрэд: 0.13   ping: 42   bid: 0.010901   ask: 0.010915
# QKCBUSD . спрэд: 0.14   ping: 59   bid: 0.010901   ask: 0.010916
# QKCBUSD . спрэд: 0.39   ping: 32   bid: 0.010902   ask: 0.010945
# QKCBUSD . спрэд: 0.43   ping: 24   bid: 0.010898   ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0
ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:-0.01
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:-0.01
# sleep:  20.162333680721005
#
# --------------------------------------------------------------------------------
# шаг 15
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.15  B:0.037   <>:-0.07
# QKCBUSD . спрэд: 0.04   ping: 62   bid: 0.010891   ask: 0.010895
# QKCBUSD . спрэд: 0.48   ping: 50   bid: 0.010891   ask: 0.010944
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.15  B:0.037   <>:0.00
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.15  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.15  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.15  B:0.037   <>:0.00
# sleep:  11.799030186260776
#
# --------------------------------------------------------------------------------
# шаг 16
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.08
# QKCBUSD . спрэд: 0.41   ping: 47   bid: 0.010898   ask: 0.010943
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# sleep:  5.725628266938856
#
# --------------------------------------------------------------------------------
# шаг 17
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.41   ping: 46   bid: 0.010898   ask: 0.010943
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------WORK_USD
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# New W_usd: 14.33
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# sleep:  18.921956262520663
#
# --------------------------------------------------------------------------------
# шаг 18
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:-0.03
# QKCBUSD . спрэд: 0.42   ping: 57   bid: 0.010896   ask: 0.010942
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:0.00
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:0.00
# sleep:  11.907074637309913
#
# --------------------------------------------------------------------------------
# шаг 19
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.42   ping: 40   bid: 0.010896   ask: 0.010942
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:0.00
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.2  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.02
# sleep:  22.438644867109275
#
# --------------------------------------------------------------------------------
# шаг 20
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.43   ping: 63   bid: 0.010897   ask: 0.010944
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# sleep:  23.51290318452962
#
# --------------------------------------------------------------------------------
# шаг 21
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.43   ping: 47   bid: 0.010897   ask: 0.010944
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:0.00
# sleep:  26.779835610813084
#
# --------------------------------------------------------------------------------
# шаг 22
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:0.02
# QKCBUSD . спрэд: 0.42   ping: 48   bid: 0.010899   ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:0.00
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:0.00
# sleep:  29.89523591648323
#
# --------------------------------------------------------------------------------
# шаг 23
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.22  B:0.037   <>:-0.02
# QKCBUSD . спрэд: 0.39   ping: 35   bid: 0.010897   ask: 0.01094
# QKCBUSD . спрэд: 0.38   ping: 42   bid: 0.010897   ask: 0.010939
# QKCBUSD . спрэд: 0.46   ping: 48   bid: 0.010888   ask: 0.010938
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:-0.10
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# sleep:  5.9241963524046595
#
# --------------------------------------------------------------------------------
# шаг 24
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.46   ping: 50   bid: 0.010888   ask: 0.010938
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# sleep:  21.978904025783606
#
# --------------------------------------------------------------------------------
# шаг 25
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.47   ping: 67   bid: 0.010888   ask: 0.010939
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------WORK_USD
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# New W_usd: 14.33
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# sleep:  33.15235459629663
#
# --------------------------------------------------------------------------------
# шаг 26
#
# ------------BUY - SELL
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.11
# QKCBUSD . спрэд: 0.43   ping: 57   bid: 0.010898   ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
#
# ------------SELL - BUY
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:227.0(2) q:13.45(13)   bq:15.92  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.23  B:0.037   <>:0.00
# sleep:  35.59196576291238
#
# --------------------------------------------------------------------------------
# шаг 27
#
# ------------BUY - SELL
# b1 b:227.0(2) q:52.62(53)   bq:55.1  B:0.059   <>:39.18
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.32  B:0.037   <>:0.09
# QKCBUSD . спрэд: 0.35   ping: 47   bid: 0.010907   ask: 0.010945
# QKCBUSD . спрэд: 0.32   ping: 63   bid: 0.01091   ask: 0.010945
# QKCBUSD . спрэд: 0.4   ping: 62   bid: 0.010901   ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:52.62(53)   bq:55.09  B:0.059   <>:-0.01
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.26  B:0.037   <>:-0.06
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:52.62(53)   bq:55.09  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.29  B:0.037   <>:0.03
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:52.62(53)   bq:55.09  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.29  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.010943 quantity: 4724
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:4724 exQty:0
# o2 False
# sell_buy() False
#
# b1 b:4951.0(54) q:0.93(1)   bq:54.89  B:0.059   <>:-0.20
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:-0.05
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:4951.0(54) q:0.93(1)   bq:54.89  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.24  B:0.037   <>:0.00
# sleep:  36.638631031168174
#
# --------------------------------------------------------------------------------
# шаг 28
#
# ------------BUY - SELL
# b1 b:4951.0(54) q:0.93(1)   bq:54.89  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.25  B:0.037   <>:0.01
# QKCBUSD . спрэд: 0.41   ping: 46   bid: 0.0109   ask: 0.010945
# b2 BUY  QKCBUSD price_dwn: 0.010901 quantity: 4847
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  4847
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:4847 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:104.0(1) q:0.93(1)   bq:2.06  B:0.059   <>:-52.83
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.25  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.01   ping: 46   bid: 0.0109   ask: 0.010901
# QKCBUSD . спрэд: 0.14   ping: 48   bid: 0.010931   ask: 0.010946
# QKCBUSD . спрэд: 0.13   ping: 52   bid: 0.010931   ask: 0.010945
# QKCBUSD . спрэд: 0.14   ping: 31   bid: 0.01093   ask: 0.010945
# QKCBUSD . спрэд: 0.16   ping: 38   bid: 0.010928   ask: 0.010945
# QKCBUSD . спрэд: 0.27   ping: 32   bid: 0.010915   ask: 0.010945
# QKCBUSD . спрэд: 0.41   ping: 63   bid: 0.0109   ask: 0.010945
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:104.0(1) q:53.77(54)   bq:54.9  B:0.059   <>:52.84
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.42  B:0.037   <>:0.17
#
# ------------SELL - BUY
# b1 b:104.0(1) q:53.77(54)   bq:54.9  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.42  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.010943 quantity: 4822
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:4822 exQty:0
# o2 False
# sell_buy() False
#
# b1 b:104.0(1) q:1.00(1)   bq:2.13  B:0.059   <>:-52.77
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.71  B:0.037   <>:0.29
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:104.0(1) q:1.00(1)   bq:2.13  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.71  B:0.037   <>:0.00
# sleep:  10.396892076876696
#
# --------------------------------------------------------------------------------
# шаг 29
#
# ------------BUY - SELL
# ...
# QKCBUSD . спрэд: 0.17   ping: 63   bid: 0.010944   ask: 0.010963
# QKCBUSD . спрэд: 0.16   ping: 47   bid: 0.010947   ask: 0.010964
# QKCBUSD . спрэд: 0.19   ping: 32   bid: 0.010944   ask: 0.010965
# QKCBUSD . спрэд: 0.16   ping: 53   bid: 0.010947   ask: 0.010965
# QKCBUSD . спрэд: 0.2   ping: 66   bid: 0.010944   ask: 0.010966
# QKCBUSD . спрэд: 0.16   ping: 47   bid: 0.010949   ask: 0.010966
# QKCBUSD . спрэд: 0.27   ping: 44   bid: 0.01095   ask: 0.01098
# QKCBUSD . спрэд: 0.33   ping: 46   bid: 0.010944   ask: 0.01098
# QKCBUSD . спрэд: 0.31   ping: 45   bid: 0.010946   ask: 0.01098
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:11854.0(129) q:1.27(1)   bq:130.63  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.39  B:0.037   <>:0.00
# sleep:  19.51738333397156
#
# --------------------------------------------------------------------------------
# шаг 30
#
# ------------BUY - SELL
# b1 b:11854.0(129) q:1.27(1)   bq:130.33  B:0.059   <>:-0.30
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:-0.27
# QKCBUSD . спрэд: 0.48   ping: 47   bid: 0.010888   ask: 0.01094
# b2 BUY  QKCBUSD price_dwn: 0.010889 quantity: 11605
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  11605
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:11605 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:249.0(3) q:12.41(12)   bq:15.11  B:0.059   <>:-115.22
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.12  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.01   ping: 30   bid: 0.010888   ask: 0.010889
# QKCBUSD . спрэд: 0.11   ping: 47   bid: 0.010876   ask: 0.010888
# QKCBUSD . спрэд: 0.1   ping: 50   bid: 0.010877   ask: 0.010888
# QKCBUSD . спрэд: 0.38   ping: 16   bid: 0.01089   ask: 0.010932
# QKCBUSD . спрэд: 0.21   ping: 45   bid: 0.01089   ask: 0.010913
# QKCBUSD . спрэд: 0.22   ping: 43   bid: 0.010889   ask: 0.010913
# QKCBUSD . спрэд: 0.21   ping: 45   bid: 0.010889   ask: 0.010912
# QKCBUSD . спрэд: 0.2   ping: 49   bid: 0.010889   ask: 0.010911
# QKCBUSD . спрэд: 0.15   ping: 50   bid: 0.010889   ask: 0.010905
# QKCBUSD . спрэд: 0.19   ping: 32   bid: 0.010889   ask: 0.01091
# QKCBUSD . спрэд: 0.16   ping: 41   bid: 0.010889   ask: 0.010906
# QKCBUSD . спрэд: 0.19   ping: 37   bid: 0.010889   ask: 0.01091
# QKCBUSD . спрэд: 0.16   ping: 31   bid: 0.010889   ask: 0.010906
# QKCBUSD . спрэд: 0.19   ping: 47   bid: 0.010889   ask: 0.01091
# QKCBUSD . спрэд: 0.17   ping: 48   bid: 0.010889   ask: 0.010907
# QKCBUSD . спрэд: 0.19   ping: 44   bid: 0.010889   ask: 0.01091
# QKCBUSD . спрэд: 0.18   ping: 63   bid: 0.010889   ask: 0.010909
# QKCBUSD . спрэд: 0.17   ping: 46   bid: 0.010889   ask: 0.010907
# QKCBUSD . спрэд: 0.16   ping: 41   bid: 0.010889   ask: 0.010906
# QKCBUSD . спрэд: 0.17   ping: 46   bid: 0.010889   ask: 0.010908
# QKCBUSD . спрэд: 0.19   ping: 31   bid: 0.010889   ask: 0.01091
# QKCBUSD . спрэд: 0.16   ping: 63   bid: 0.010889   ask: 0.010906
# QKCBUSD . спрэд: 0.17   ping: 44   bid: 0.010889   ask: 0.010908
# QKCBUSD . спрэд: 0.19   ping: 47   bid: 0.010889   ask: 0.01091
# QKCBUSD . спрэд: 0.2   ping: 50   bid: 0.010889   ask: 0.010911
# QKCBUSD . спрэд: 0.38   ping: 47   bid: 0.01087   ask: 0.010911
# QKCBUSD . спрэд: 0.2   ping: 80   bid: 0.010889   ask: 0.010911
# QKCBUSD . спрэд: 0.39   ping: 35   bid: 0.010868   ask: 0.010911
# QKCBUSD . спрэд: 0.49   ping: 65   bid: 0.01087   ask: 0.010923
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:249.0(3) q:127.63(128)   bq:130.34  B:0.059   <>:115.23
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.92  B:0.037   <>:-0.20
#
# ------------SELL - BUY
# b1 b:249.0(3) q:127.63(128)   bq:130.34  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.92  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.010921 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# sell_buy() False
#
# b1 b:249.0(3) q:12.44(12)   bq:15.15  B:0.059   <>:-115.19
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.47  B:0.037   <>:0.55
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:249.0(3) q:12.44(12)   bq:15.15  B:0.059   <>:0.00
# b2 b:10775.0(118) q:3867.80(3868)   bq:3985.47  B:0.037   <>:0.00
# sleep:  35.03196457248444
#
# --------------------------------------------------------------------------------
# шаг 31
#
# ------------BUY - SELL
# b1 b:10797.0(117) q:12.44(12)   bq:129.82  B:0.059   <>:114.67
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.95  B:0.037   <>:-0.52
# QKCBUSD . спрэд: 0.36   ping: 46   bid: 0.010872   ask: 0.010911
# QKCBUSD . спрэд: 0.05   ping: 28   bid: 0.010867   ask: 0.010872
# QKCBUSD . спрэд: 0.4   ping: 30   bid: 0.010867   ask: 0.010911
# QKCBUSD . спрэд: 0.07   ping: 63   bid: 0.010859   ask: 0.010867
# QKCBUSD . спрэд: 0.13   ping: 46   bid: 0.010852   ask: 0.010866
# QKCBUSD . спрэд: 0.17   ping: 47   bid: 0.010848   ask: 0.010866
# QKCBUSD . спрэд: 0.15   ping: 62   bid: 0.01085   ask: 0.010866
# QKCBUSD . спрэд: 0.17   ping: 32   bid: 0.010848   ask: 0.010866
# QKCBUSD . спрэд: 0.5   ping: 30   bid: 0.010848   ask: 0.010902
# b2 BUY  QKCBUSD price_dwn: 0.010849 quantity: 10570
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  10570
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10570 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:227.0(2) q:127.11(127)   bq:129.57  B:0.059   <>:-0.25
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.71  B:0.037   <>:-0.24
# QKCBUSD . спрэд: 0.47   ping: 49   bid: 0.01085   ask: 0.010901
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:127.11(127)   bq:129.57  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.71  B:0.037   <>:0.00
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:127.11(127)   bq:129.57  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.71  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:227.0(2) q:127.11(127)   bq:129.57  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.71  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.010899 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# sell_buy() False
# b1 b:10775.0(117) q:12.15(12)   bq:129.06  B:0.059   <>:-0.51
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.71  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:10775.0(117) q:12.15(12)   bq:129.06  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.71  B:0.037   <>:0.00
# sleep:  12.668474668584334
#
# --------------------------------------------------------------------------------
# шаг 32
#
# ------------BUY - SELL
# b1 b:10775.0(117) q:12.15(12)   bq:129.06  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.71  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.47   ping: 39   bid: 0.01085   ask: 0.010901
# b2 BUY  QKCBUSD price_dwn: 0.010851 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  10548
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:227.0(2) q:12.15(12)   bq:14.61  B:0.059   <>:-114.45
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.71  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.01   ping: 62   bid: 0.01085   ask: 0.010851
# QKCBUSD . спрэд: 0.39   ping: 38   bid: 0.01086   ask: 0.010902
# QKCBUSD . спрэд: 0.47   ping: 46   bid: 0.01086   ask: 0.010911
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:126.61(127)   bq:129.07  B:0.059   <>:114.46
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.82  B:0.037   <>:0.11
#
# ------------SELL - BUY
# b1 b:227.0(2) q:126.61(127)   bq:129.07  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.82  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.010909 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# sell_buy() False
#
# b1 b:10775.0(117) q:11.54(12)   bq:128.55  B:0.059   <>:-0.52
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.82  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:10775.0(117) q:11.54(12)   bq:128.55  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.82  B:0.037   <>:0.00
# sleep:  26.586684486835537
#
# --------------------------------------------------------------------------------
# шаг 33
#
# ------------BUY - SELL
# b1 b:10775.0(117) q:11.54(12)   bq:128.55  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.82  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.45   ping: 44   bid: 0.01086   ask: 0.010909
# b2 BUY  QKCBUSD price_dwn: 0.010861 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  10548
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:227.0(2) q:11.54(12)   bq:14.0  B:0.059   <>:-114.55
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.82  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.01   ping: 15   bid: 0.01086   ask: 0.010861
# QKCBUSD . спрэд: 0.1   ping: 41   bid: 0.01085   ask: 0.010861
# QKCBUSD . спрэд: 0.4   ping: 30   bid: 0.010867   ask: 0.010911
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:227.0(2) q:126.10(126)   bq:128.56  B:0.059   <>:114.56
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.89  B:0.037   <>:0.07
#
# ------------BUSD_TO_BNB
# b1 b:227.0(2) q:126.10(126)   bq:128.56  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.89  B:0.037   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------WORK_USD
# b1 b:227.0(2) q:126.10(126)   bq:128.56  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.89  B:0.037   <>:0.00
# New W_usd: 115.71
#
# ------------SELL - BUY
# b1 b:227.0(2) q:126.10(126)   bq:128.56  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.89  B:0.037   <>:0.00
# b2 SELL  QKCBUSD price_up: 0.010909 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# sell_buy() False
#
# b1 b:10775.0(117) q:11.03(11)   bq:128.12  B:0.059   <>:-0.44
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.89  B:0.037   <>:0.00
# qty < usd_min  -->
# sell_buy() True
#
# b1 b:10775.0(117) q:11.03(11)   bq:128.12  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.89  B:0.037   <>:0.00
# sleep:  30.194143745086727
#
# --------------------------------------------------------------------------------
# шаг 34
#
# ------------BUY - SELL
# b1 b:10775.0(117) q:11.03(11)   bq:128.12  B:0.059   <>:0.00
# b2 b:10775.0(117) q:3867.80(3868)   bq:3984.89  B:0.037   <>:0.00
# QKCBUSD . спрэд: 0.39   ping: 47   bid: 0.010867   ask: 0.01091
# QKCBUSD . спрэд: 0.38   ping: 48   bid: 0.010867   ask: 0.010908
# QKCBUSD . спрэд: 0.39   ping: 71   bid: 0.010867   ask: 0.010909
# QKCBUSD . спрэд: 0.09   ping: 56   bid: 0.0109   ask: 0.01091
# QKCBUSD . спрэд: 0.37   ping: 30   bid: 0.010867   ask: 0.010907
# QKCBUSD . спрэд: 0.39   ping: 31   bid: 0.010867   ask: 0.010909
# QKCBUSD . спрэд: 0.36   ping: 40   bid: 0.01087   ask: 0.010909
# QKCBUSD . спрэд: 0.35   ping: 48   bid: 0.010871   ask: 0.010909
# QKCBUSD . спрэд: 0.28   ping: 63   bid: 0.010871   ask: 0.010901
# QKCBUSD . спрэд: 0.39   ping: 52   bid: 0.010858   ask: 0.010901
# QKCBUSD . спрэд: 0.28   ping: 78   bid: 0.010871   ask: 0.010902
# QKCBUSD . спрэд: 0.39   ping: 48   bid: 0.010858   ask: 0.0109
# QKCBUSD . спрэд: 0.38   ping: 35   bid: 0.010858   ask: 0.010899
# QKCBUSD . спрэд: 0.24   ping: 44   bid: 0.010873   ask: 0.010899
# QKCBUSD . спрэд: 0.27   ping: 32   bid: 0.010873   ask: 0.010902
# QKCBUSD . спрэд: 0.26   ping: 51   bid: 0.010873   ask: 0.010901
# QKCBUSD . спрэд: 0.34   ping: 45   bid: 0.010873   ask: 0.01091
# QKCBUSD . спрэд: 0.32   ping: 48   bid: 0.010873   ask: 0.010908
# QKCBUSD . спрэд: 0.35   ping: 44   bid: 0.010873   ask: 0.010911
# QKCBUSD . спрэд: 0.34   ping: 31   bid: 0.010873   ask: 0.01091
# QKCBUSD . спрэд: 0.32   ping: 33   bid: 0.010873   ask: 0.010908
# QKCBUSD . спрэд: 0.31   ping: 49   bid: 0.010874   ask: 0.010908
# QKCBUSD . спрэд: 0.34   ping: 32   bid: 0.010874   ask: 0.010911
# QKCBUSD . спрэд: 0.33   ping: 29   bid: 0.010874   ask: 0.01091
# QKCBUSD . спрэд: 0.31   ping: 44   bid: 0.010874   ask: 0.010908
# QKCBUSD . спрэд: 0.32   ping: 44   bid: 0.010876   ask: 0.010911
# QKCBUSD . спрэд: 0.39   ping: 46   bid: 0.010876   ask: 0.010919
# QKCBUSD . спрэд: 0.38   ping: 31   bid: 0.010876   ask: 0.010918
# QKCBUSD . спрэд: 0.32   ping: 47   bid: 0.010873   ask: 0.010908
# QKCBUSD . спрэд: 0.31   ping: 35   bid: 0.010873   ask: 0.010907
# QKCBUSD . спрэд: 0.35   ping: 58   bid: 0.010873   ask: 0.010911
# QKCBUSD . спрэд: 0.34   ping: 47   bid: 0.010873   ask: 0.01091
# QKCBUSD . спрэд: 0.26   ping: 41   bid: 0.010873   ask: 0.010901
# QKCBUSD . спрэд: 0.25   ping: 78   bid: 0.010873   ask: 0.0109
# QKCBUSD . спрэд: 0.35   ping: 33   bid: 0.010873   ask: 0.010911
# QKCBUSD . спрэд: 0.34   ping: 44   bid: 0.010873   ask: 0.01091
# QKCBUSD . спрэд: 0.41   ping: 59   bid: 0.010877   ask: 0.010922
# b2 BUY  QKCBUSD price_dwn: 0.010878 quantity: 10548
# b2  {"code":-2010,"msg":"This action is disabled on this account."}
# bot1 try SELL  10548
# b2 setOrder o NULL
# b1 setOrder QKCBUSD origQty:10548 exQty:0
# o2 False
# buy_sell() False
#
# b1 b:227.0(2) q:11.03(11)   bq:13.5  B:0.059   <>:-114.62
# b2 b:10775.0(117) q:3867.80(3868)   bq:3985.0  B:0.037   <>:0.11
# QKCBUSD . спрэд: 0.01   ping: 34   bid: 0.010877   ask: 0.010878
# QKCBUSD . спрэд: 0.05   ping: 40   bid: 0.010873   ask: 0.010878

# %%
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\2\ipykernel_6416\4000743260.py in <module>
# ----> 1 f.close()
#
# NameError: name 'f' is not defined

# %%
#Балансы

get_new_Work_usd()

#
if bal['bot1']['quote_in_usd'] > Work_usd and bal['bot2']['base_in_usd'] > Work_usd :
  print('need SellBuy')

if bal['bot1']['base_in_usd'] > Work_usd and bal['bot2']['quote_in_usd'] > Work_usd :
  print('need BuySell')

if bal['bot1']['base_in_usd'] > Work_usd and bal['bot2']['base_in_usd'] > Work_usd :
  print('need sell base')

if bal['bot1']['quote_in_usd'] > Work_usd and bal['bot2']['quote_in_usd'] > Work_usd :
  print('need buy base')
# Out:
# 03.02.2023 18:54:51 b1 b:227.0(2) q:40.87(41)   bq:43.34  B:0.059   <>:43.34
# 03.02.2023 18:54:51 b2 b:10775.0(117) q:3867.80(3868)   bq:3984.96  B:0.037   <>:3984.96
# New W_usd: 39.01
# need SellBuy
# need buy base

# %% [markdown]
# ## Начальная закупка

# %%
# Начальная закупка base на bot1   и quote на bot2
#get_new_Work_usd()
Work_usd  = 300 # количество USD для работы/ 

# bot1 Купить baseAsset из Work_usd
try :
  print(usd_to_base( bot1, Work_usd))
except :
  print('b1 не купили')  
# bot2 Купить quoteAsset из Work_usd
try: 
  print(usd_to_quote(bot2, Work_usd))
except :
  print('b2 не купили')
# Out:
# b1  usd_to_base: QKCBUSD 300
# QKCBUSD origQty:28356 exQty:28356
# {'symbol': 'QKCBUSD', 'orderId': 11877855, 'orderListId': -1, 'clientOrderId': 'Du1hZNGoz2cVT41z4Xb6kd', 'transactTime': 1675332938209, 'price': '0.00000000', 'origQty': '28356.00000000', 'executedQty': '28356.00000000', 'cummulativeQuoteQty': '299.69192700', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1675332938209, 'fills': [{'price': '0.01056400', 'qty': '3022.00000000', 'commission': '0.00007209', 'commissionAsset': 'BNB', 'tradeId': 399734}, {'price': '0.01056500', 'qty': '2687.00000000', 'commission': '0.00006410', 'commissionAsset': 'BNB', 'tradeId': 399735}, {'price': '0.01056600', 'qty': '3020.00000000', 'commission': '0.00007204', 'commissionAsset': 'BNB', 'tradeId': 399736}, {'price': '0.01057000', 'qty': '13300.00000000', 'commission': '0.00031730', 'commissionAsset': 'BNB', 'tradeId': 399737}, {'price': '0.01057200', 'qty': '6327.00000000', 'commission': '0.00015094', 'commissionAsset': 'BNB', 'tradeId': 399738}], 'selfTradePreventionMode': 'NONE'}
# o NULL
# {'не перекидываем ', 'BUSDBUSD'}

# %% [markdown]
# ## распродажа монет

# %%
# Перегоняем Quote и Base в USD
bal = get_balances() 

if bal['bot1']['baseAsset']  > bal['base_min']  : 
    a=0
    try : base_to_usd(bot1, bal['bot1']['baseAsset'])
    except : print('err bot1 base_to_usd')
     
if bal['bot1']['quoteAsset'] > bal['quote_min'] : 
    a=0
    try : quote_to_usd(bot1, bal['bot1']['quoteAsset'])
    except : print('err bot1 quote_to_usd')

        
if bal['bot2']['baseAsset']  > bal['base_min']  : 
    a=0
    try : base_to_usd(bot2, bal['bot2']['baseAsset'])   
    except : print('err bot2 base_to_usd')
if bal['bot2']['quoteAsset'] > bal['quote_min'] : 
    a=0
    try : quote_to_usd(bot2, bal['bot2']['quoteAsset'])
    except : print('err bot2 quote_to_usd')
# Out:
# b1 b:8142.2675(310) q:391.63(6)   bq:316.04  B:0.029   <>:-0.08
# b2 b:170.863(7) q:222109.68(3166)   bq:3172.72  B:0.059   <>:0.00
# b1  base_to_usd: ARPABUSD 8142.2675
# ARPABUSD origQty:8134.1 exQty:8134.1
# b2  quote_to_usd: BUSDRUB 222109.678804
# BUSDRUB origQty:3163 exQty:3163

# %%
f = open('client_report.txt','w')

f.write(str(client_report))

f.close()

# %% [markdown]
# ## Балансы > 0

# %%
# Balances > 0

print('bot1')
acc = bot1.account()['balances']
for i in range( len(acc) ):
  if float(acc[i]['free']) > 0 :
    print(acc[i])

print('bot2')
acc = bot2.account()['balances']
for i in range( len(acc) ):
  if float(acc[i]['free']) > 0 :
    print(acc[i])
# Out:
# bot1
# {'asset': 'BTC', 'free': '0.00004355', 'locked': '0.00000000'}
# {'asset': 'BNB', 'free': '0.05874604', 'locked': '0.00000000'}
# {'asset': 'USDT', 'free': '0.18475859', 'locked': '0.00000000'}
# {'asset': 'QKC', 'free': '227.00000000', 'locked': '7805.00000000'}
# {'asset': 'FTM', 'free': '13.40000000', 'locked': '0.00000000'}
# {'asset': 'BUSD', 'free': '40.87183100', 'locked': '0.00000000'}
# {'asset': 'RUB', 'free': '391.63011500', 'locked': '266.40000000'}
# {'asset': 'ARPA', 'free': '8.16750000', 'locked': '0.00000000'}
# bot2
# {'asset': 'BNB', 'free': '0.03740883', 'locked': '0.00000000'}
# {'asset': 'SNT', 'free': '1.42400000', 'locked': '0.00000000'}
# {'asset': 'USDT', 'free': '0.38704025', 'locked': '0.00000000'}
# {'asset': 'QKC', 'free': '10775.00000000', 'locked': '0.00000000'}
# {'asset': 'FTM', 'free': '0.30000000', 'locked': '0.00000000'}
# {'asset': 'BUSD', 'free': '3867.80494535', 'locked': '0.00000000'}
# {'asset': 'RUB', 'free': '225.22880400', 'locked': '0.00000000'}
# {'asset': 'ARPA', 'free': '170.86300000', 'locked': '0.00000000'}
# {'asset': 'BRL', 'free': '1.62690000', 'locked': '0.00000000'}
# {'asset': 'C98', 'free': '0.50000000', 'locked': '0.00000000'}

# %% [markdown]
# ## createOrders

# %% [markdown]
# # START

# %%
atob(bot2, 'BUSD', 'USDT', 20, 'a')
# Out:
# ab: BUSDUSDT
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\2\ipykernel_6212\1856942424.py in atob(bot, a, b, qty, qty_in_A_or_B)
#       9         if qty_in_A_or_B == 1 or qty_in_A_or_B == 'a':
# ---> 10             print(bot.createOrder(
#      11             symbol        = pair,
#
# ~\AppData\Local\Temp\2\ipykernel_6212\1486528545.py in wrapper(*args, **kwargs)
#      84             kwargs.update(command=name)
# ---> 85             return self.call_api(**kwargs)
#      86         return wrapper
#
# ~\AppData\Local\Temp\2\ipykernel_6212\1486528545.py in call_api(self, **kwargs)
#     121         if 'code' in response.text:
# --> 122             raise Exception(response.text)
#     123
#
# Exception: {"code":-2010,"msg":"This action is disabled on this account."}
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\2\ipykernel_6212\1350489153.py in <module>
# ----> 1 atob(bot2, 'BUSD', 'USDT', 20, 'a')
#
# ~\AppData\Local\Temp\2\ipykernel_6212\1856942424.py in atob(bot, a, b, qty, qty_in_A_or_B)
#      20     except :
#      21         pair = b+a
# ---> 22         sett[ pair ];
#      23         print('ba:', pair)
#      24
#
# KeyError: 'USDTBUSD'
