# %%
M
28.12.22 активировал 200р
8 905 026 1886
билайн
eidosrf@bk.ru

B
30.12.22 активировал 150р
960 058 1108
9600743037
билайн
bathnauka@yandex.ru

# %%
maratrinatovic52@gmail.com
123321kokosAz4!

# %%
#Суммарный баланс по всем нашим счетам

import import_ipynb
b1_API_KEY = ''; b1_API_SECRET = ''; b2_API_KEY = ''; b2_API_SECRET = ''
# %run fn.ipynb

As=0; Bs=0; Ns=0; Ms=0; Ks=0



print('Нияз личный N')
#b2_API_KEY='Sqv4OEOXBXjNmxVNrhlNpHbCeRFoS13amCqlKgGX7usBcqMC4zCuSZhpsLtWdlwd'
#b2_API_SECRET='xRYlFAOWVaQhGsOKuQcT1L6doSbnOaIIv4HMtJgY2OjEEBf25AotB28uqHebfe1y'
b2_API_KEY='uerd5dKR9Bj0SiTxSrFuElIEvUdga9tjH0QayP9TLnEzjMVDKYHBbDmwqsOCn4Ze'  # 31.01.23
b2_API_SECRET='lRzQTC0FYoHZxD00tDvaR76UkQr4QQyVkL2fhn66GSpbyBgEZ2GOjI7hJipJ5wCA'
bot2 = Binance( API_KEY= b2_API_KEY, API_SECRET= b2_API_SECRET, bname= 'b2' )    
acc2 = getBalancesInUSD(bot2)
for i in range( len(acc2) ) : Ns = Ns + acc2[i].get( 'free_usd' , 0 ) + acc2[i].get( 'locked_usd' , 0 )

#print('Казахстан K')
#b2_API_KEY='gmpUYVzZYuW0tcmRpON57TzsNJ0qYnhyNhIlVq4mtPu6Pw0B6k3hRKpuETG66kgG'
#b2_API_SECRET='8W1OwuoIPUJrzx3UnLk7RaA0MU2ZL4gNbgX45sgkXgngtuCENCEA5N9EC9urIney'
#04.01.23
#b2_API_KEY='BBVB7MUNxnHKwrtf5zTolsFoQQYR48LQMrCdOgAnvvQaAswgCvmH1Sn2xflMcyV6'
#b2_API_SECRET='KEusjlIsaFnkAdinOrdCALHZpdIsIjeZEtKG6DgPv64Xe12uTIc09zhQ7zWiSfQv'
#bot2 = Binance( API_KEY= b2_API_KEY, API_SECRET= b2_API_SECRET, bname= 'b2' )    
#acc2 = getBalancesInUSD(bot2)
#for i in range( len(acc2) ) : Ks = Ks + acc2[i].get( 'free_usd' , 0 ) + acc2[i].get( 'locked_usd' , 0 )
            
print('Саша личный A')          
#b2_API_KEY='NTxq3UElmu3Sh8NZnp7kkZFejeua0UeAxFS112B5QXRc9Qd056lptSRJQFSNMGxD'
#b2_API_SECRET='Lx3PsUWcmAJd6KTYVudCY2KRIWwS6EcthvMSNhu6l0mPWAk25YwIzH9qYaYT3FnC' 
b2_API_KEY='ln5BnaxMp7ExRnfgrtMf5Nvhdvq184rYGR8yQJwD6ptOri4yXmx5ermh8LescK5n'  #14.01.23
b2_API_SECRET='JdKOdoQPsPiXbT2dBGpp69KDqnHdoZNQQbK1hV3kekLPO7jZN3et6qdeLPmBdcw3' 
bot2 = Binance( API_KEY= b2_API_KEY, API_SECRET= b2_API_SECRET, bname= 'b2' )    
acc2 = getBalancesInUSD(bot2)
for i in range( len(acc2) ) : As = As + acc2[i].get( 'free_usd' , 0 ) + acc2[i].get( 'locked_usd' , 0 )

print('мамин ак M')
b2_API_KEY='M3QxGidfeS87LAeP3gEwvw3dlR7A5NEMKc4SRbG5CqE487DR8SdsH3w9URTDw2DR'
b2_API_SECRET='lyKDwGnzNE3GFQHNVhsVWeiezp9dRpxhXdVCAkDiW6IIHqDnzAa8g79dxeVRNctn' 
bot2 = Binance( API_KEY= b2_API_KEY, API_SECRET= b2_API_SECRET, bname= 'b2' )    
acc2 = getBalancesInUSD(bot2)
for i in range( len(acc2) ) : Ms = Ms + acc2[i].get( 'free_usd' , 0 ) + acc2[i].get( 'locked_usd' , 0 )

print('Нияз ак B')
b2_API_KEY='RY6um3Bjtm5Ht1vvLY4eYHdYjfA14SdvoKrCs0ViKMtGJ96hkF8nAlggFRgisc7E'
b2_API_SECRET='kv47sJleHB6nm6jeDVCqoSX1HETKjfb5Y8swXV91UVgcujjVkCzG1gzMMHowr2eo' 
bot2 = Binance( API_KEY= b2_API_KEY, API_SECRET= b2_API_SECRET, bname= 'b2' )    
acc2 = getBalancesInUSD(bot2)
for i in range( len(acc2) ) : Bs = Bs + acc2[i].get( 'free_usd' , 0 ) + acc2[i].get( 'locked_usd' , 0 )
 
print('')
print('A:',As, ' B:',Bs, ' N:', Ns, ' M:', Ms)#, ' K:', Ks)   
print('ИТОГО: ',As + Bs + Ns + Ms)# + Ks)
# Out:
# Нияз личный N
# {'asset': 'BNB', 'free_usd': 74.56, 'locked_usd': 0.0, 'free': 0, 'locked': 0}
# {'asset': 'BUSD', 'free_usd': 1827.54, 'locked_usd': 0.0}
# {'asset': 'HARD', 'free_usd': 194.03, 'locked_usd': 0.0, 'free': 961, 'locked': 0}
# Саша личный A
# {'asset': 'BNB', 'free_usd': 19.97, 'locked_usd': 0.0, 'free': 0, 'locked': 0}
# {'asset': 'USDT', 'free_usd': 336.32, 'locked_usd': 0.0, 'free': 336, 'locked': 0}
# {}
# {}
# мамин ак M
# {'asset': 'BNB', 'free_usd': 13.67, 'locked_usd': 0.0, 'free': 0, 'locked': 0}
# {'asset': 'USDT', 'free_usd': 3548.88, 'locked_usd': 0.0, 'free': 3549, 'locked': 0}
# {'asset': 'ALGO', 'free_usd': 0.19, 'locked_usd': 0.0, 'free': 1, 'locked': 0}
# {'asset': 'BUSD', 'free_usd': 281.93, 'locked_usd': 0.0}
# {'asset': 'RUB', 'free_usd': 0.5, 'locked_usd': 0.0, 'free': 36, 'locked': 0}
# {'asset': 'BRL', 'free_usd': 0.08, 'locked_usd': 0.0, 'free': 0, 'locked': 0}
# {'asset': 'SOL', 'free_usd': 10.71, 'locked_usd': 0.0, 'free': 0, 'locked': 0}
# ...

# %%
A: 3455.83  B: 909.99  N: 948.22  M: 1839.4599999999998  K: 857.34
ИТОГО:  8010.84

# %%
М 585 ВВХ
Н 350 Коровка
М 100 Эксплойт
Н 200 ВВХ 
Н 30

Верифай

# %% [markdown]
# # Качаем на K

# %% [markdown]
# # Качаем на A

# %% [markdown]
# # Качаем на N

# %% [markdown]
# # Качаем на M

# %%
b1_API_KEY='qhIu4sd7RqBr3HaSJfr48HAeOLgaLZNZN4kJgaMQvE5yPiynydaZwOMZYvIyQt5u';  N=39; percent=65
b1_API_SECRET='jTzgxL2wIl0oESAKKukbcgzPnvaU7sgHctxzqctfHeYFFBmx5TghG7Btc1AEHOKE' #21.01.23


qhIu4sd7RqBr3HaSJfr48HAeOLgaLZNZN4kJgaMQvE5yPiynydaZwOMZYvIyQt5u
было:  3067
ушло: 3036.65 $
сейчас: 30.35
к нам пришло: 2022.05
 2022.05/3036.65 = 66.59 % 

отдаем 65 % : 1314.33 $
клиент получил 43 % от депозита
отдавали:  0 . Остались должны:  1314
        
РАССЧИТАН

# %%
b1_API_KEY='45qy172nZkOXEh2kvPhSGhI3sWdkAWBMsehcZ4JB5CNkWw3eZwxLdk31Bv2zg1f3';  N=40; percent=60
b1_API_SECRET='ADNSE8I9j57iorLhhXRtIEPjKXB3aWrXqEGQTKfbtmyVAFoBcwnJ6wCq405K2gyl' #25.01.23


45qy172nZkOXEh2kvPhSGhI3sWdkAWBMsehcZ4JB5CNkWw3eZwxLdk31Bv2zg1f3
было:  656
ушло: 629.98 $
сейчас: 26.02
к нам пришло: 360.63
 360.63/629.98 = 57.24 % 

отдаем 60 % : 216.38 $
клиент получил 33 % от депозита
отдавали:  0 . Остались должны:  216
        
РАССЧИТАН

# %%
b1_API_KEY='C628WbMnwfOt4PuE8KaMBIxPCnjqgJJUKMxy0znA5hEyAKIATXQYoUYZaxAzJ6MB';  N=41; percent=60
b1_API_SECRET='UajI4za4JlnhOQgnaNXQ515JEfKEcAXHDDfLBgEO5RkCRJCeF3ATQbAJimQEqEbT' #27.01.23
трэйдинг закрыт

# %%
b1_API_KEY='pSPbVD9tOJwaXrUIeLwJPWKlqOj6CGGD0i8Vd1bZ6pQ19bKxcAN2Wdps2It1w1X5';  N=42; percent=50
b1_API_SECRET='Hb4cS7etttMaXFpgiBTPhzsq6btlduwTU9JDZfuzuKkKlwvK9FqjUUCJTg6vuZQa' #28.01.23

# %%
b1_API_KEY='6679RLHPTGPh1tVFZzEMCklt1AIHRSNIAYFTo8UBMK5q7uB68Ks0ykLlyYa3kmRi';  N=43; percent=50
b1_API_SECRET='S99ul1GxlQHmZknc8BI0fRg5htPxP7faAfB3lHbCPa8urXrJXntk0oELzICmKNh8' #28.01.23
Invalid API-key

# %%
b1_API_KEY='KkDkjgzhShccJMkurhcb2814rLMPT6b6hy3gwA1D4ayiTfn7Yvyn2Td6yLsSkieh';  N=44; percent=60
b1_API_SECRET='4OUptIF8AQiX9rccIVU1tyUVxq3ZRNsG6AYcEJGbEo4hiyHGfNH7wtFpHO5nNqeU' #29.01.23


KkDkjgzhShccJMkurhcb2814rLMPT6b6hy3gwA1D4ayiTfn7Yvyn2Td6yLsSkieh
было:  5361
ушло: 5269.21 $
сейчас: 91.79
к нам пришло: 3390.42
 3390.42/5269.21 = 64.34 % 

отдаем 60 % : 2034.25 $
клиент получил 38 % от депозита
отдавали:  250 . Остались должны:  1784
        
02.02.23
ОТКЛЮЧЕН
РАССЧИТАН

# %%
b1_API_KEY='KyNhZ1MX44WQvpITo4Gymln2eZa2BtAeSYidN7LaPe873GcwBLgWYTBX5uct8pCA';  N=45; percent=60
b1_API_SECRET='rAWNHeesElERd8CLyzSal8poP9sDCCii5yZdsREEdhpkDXcHIlIYLakcCACZEmo3' #30.01.23

KyNhZ1MX44WQvpITo4Gymln2eZa2BtAeSYidN7LaPe873GcwBLgWYTBX5uct8pCA
было:  4616
ушло: 4524.46 $
сейчас: 91.54
к нам пришло: 3192.04
 3192.04/4524.46 = 70.55 % 

отдаем 60 % : 1915.22 $
клиент получил 41 % от депозита
отдавали:  1878 . Остались должны:  37
РАССЧИТАН

# %% [markdown]
# # Качаем на B

# %% [markdown]
# # Перед добавлением ОБНОВЛЯТЬ!

# %%
20.01.23 Новый API 38. Оплата гаранту M-307$
20.01.23 M+707$  Доплата гаранту N-98$
21.01.23 Рассчитаен счет 38
A: 3516.88  B: 907.49  N: 307.07  M: 1675.19  K: 908.48 ИТОГО:  7315.11
21.01.23 Айрату M-100$
21.01.23 Новый API 39. без Айрата
22.01.23 Докачался. M+2022$ Отключил.
22.01.23 M-1314$ отправил на TRaqbKLYRFF247BtjpavqzXbLrhAaGFRuV
25.01.23 Новый API 40
26.01.23 Докачался. M+360$ Отключил.
26.01.23 M-216$ отправил на TUPpyKCHF9TP73EUick4Durf9ycnC4Xevk
26.01.23 M-264$ Саша заблал себе
26.01.23 N-100$ Нияз забрал себе
27.01.23 Новый API 41. Торговля запрещена. На счете 3691$
28.01.23 Новый API 42. На счете 5420$. Гаранту М-1385$. Запустил на B
28.01.23 Новый API 43. Invalid API-key
29.01.23 Новый API 44. На счете 5361$. Запустил на М
30.01.23 №44 M-250$. TJzGrW2nywKDojiifs91DDEhp7LLDkqHk8
30.01.23 Перевели всё со счета K на N
A: 3662.28  B: 2471.48  N: 1871.41  M: 1231.22  K: 1.21 ИТОГО:  9237.5
30.01.23 Саше N-1500$.  Ниязу N-100$.  Айрату N-50$  Брату K-100$
30.01.23 Новый API 45. На счете 4616$. Запустил на N
31.01.23 Перекинули B-800$ N+800$
31.01.23 Новый API счета N
31.01.23 Нияз вывел себе N-300$
01.02.23 №45 N-618$
01.02.23 Разблокировали счет A !!!
02.02.23 Остановил M. Клиенту №44 рассчитан со счета A-1784$
02.02.23 Закрыли долг Гуливеру №25 A-800$
02.02.23 Рассчитан №45 N-1259$ 
02.02.23 Рассчитан №42 A-579$ 
03.02.23 A-100  Нияз забрал 400/1000

# %%
ПОДКЛЮЧЕНИЕ СЧЕТА

1. Создаю новую карточку и Копирую новый ключ 
вставляю его сюда в таком формате
b1_API_KEY='Dnc2nQbRZbyA5UCHB7GR1jRQxXcg22a16PRLSF66w0vYPCi8QF8b7MtlZpmYrusR';  N=37; percent=50%
b1_API_SECRET='g72bOnV5vHpoSdBF3OWOuJaA9A7pXOErj2RbzOu23LgaARASpAn0gfQARpzowx3b' #17.01.23  1531.71$

Пишу дату внесения нового счета
Даю ему номер
и какой % мы долждны отдавать
(писать справа от ключа. Так удобно, чтобы в 2 строчки)

2. Копирую ключ в файл выкачки (Например K)
а раздел #1 кошелек, откуда переливаем

3. Нажимаю "Сохранить". Теперь Консоль видит файл K с новым ключом

4. Перезапускаю ядро консоли "restart the kernel" (Иначе будут данные старого счета подключенного к K)
В карточке # состояние перелива 
вбиваю название счета F = 'K' # Выбрать букву счета и запустить

Вижу какие есть монеты и общую сумму
bot1  
{'asset': 'BTC', 'free_usd': 0.03, 'locked_usd': 0.0, 'free': 0, 'locked': 0}
{'asset': 'USDT', 'free_usd': 1.53, 'locked_usd': 0.0, 'free': 2, 'locked': 0}
{'asset': 'XMR', 'free_usd': 1530.15, 'locked_usd': 0.0, 'free': 9, 'locked': 0}
(Суммы суммы указаны в $)
сейчас: 1531.71 (На счете клиента) Записываю в карточку ключа сумму на счете
на нашем счете: 915.85

Добавляю строку
b1_start = 1548;   b2_start = 918; otdali = 0; percent = 50  #  №37
b1_start - стартовая сумма на счете клиента 
b2_start - стартовая сумма на нашем счете (если по своим причинам снимали или добавляли денег, то можно +123 подсуммировать или вычесть)
otdali - сюда пишем сколько отдали клиенту по данному счету (тут тоже можно суммировать)
percent - какой % должны отдавать с выкачанного



ОБМЕН

В данном счете нужно обменять XMR в BUSD

5. Запускаю # Balances > 0
bot1  
{'asset': 'BTC', 'free': '0.00000134', 'locked': '0.00000000'}
{'asset': 'USDT', 'free': '1.52782929', 'locked': '0.00000000'}
{'asset': 'XMR', 'free': '8.98501226', 'locked': '0.00000000'}
(тут суммы указаны в токенах)
копирую 8.98501226

6. Настраиваю карточку 
# конвертируем из токена A в токен B  # qty объем указан в токене A
atob(bot1, a= 'XMR', b= 'BUSD', qty= 8.98501226, qty_in_A_or_B= 'a')

bot = bot1   #bot1 - счет клиента. #bot2 - наш счет.
qty_in_A_or_B - в какой монете указана валюта? a или b
Выполняю. Вижу что сработало.

Проверяю # состояние перелива
{'asset': 'BUSD', 'free_usd': 1546.71, 'locked_usd': 0.0}



ПОДКЛЮЧЕНИЕ ТОРГОВОЙ ПАРЫ

7. Ищу торговую пару в карточке # поиск спрэдовых окон
min_spread_in_percent = 0.7  # размер спрэда в %. 
# для пар к BUSD должен быть от 0.5% 
# на окнах 0.4% эффективность перекачки 50%. 0.5% - 55%. 0.6% - 60%. 0.7 и более - 65% и более.
#
# для пар ко всему кроме BUSD должен быть от 1.0% 
# на окнах 0.9%-1.% эффективность перекачки 45-50%. 1.3% - 55%. 1.6% - 60%. 1.7 и более - 65% и более.

find_pairs_by_spread( 'базовая', 'квотируемая', min_spread_in_percent, минимальный размер в пунктах)
вбивается базовая валюта и квотируемая. если поле пустое, то ищутся все возможные токены

Выполняю. Вижу подходящую пару
WBTCBUSD {'s%': 1.05, '    s': 22659, '    s/%': 21580, '    id': 2070}

8. Захожу в K и вбиваю настройки
#2 подготовка параметров для торговли  
min_spread_in_percent = 0.6

b = 'WBTC'; # 2/10
q = 'BUSD'; u = 'BUSD'

9. Выполняю карточку 1. и 2.
Третью пока не надо. Это рабочи цикл


ПОДГОТОВКА БАЛАНСОВ

10. Иду в карточку
# Начальная закупка base на bot1   и quote на bot2
Work_usd  = 950 # количество USD для работы/ 
Рабочая сумма должна быть меньшее по паре счетов.

Карточка
#Балансы в паре счетов
Пара WBTCBUSD
b1 b:0.04441(942) q:74.58(75)   bq:1017.0  B:0.048   <>:0.00
b2 b:0.0(0) q:1261.87(1262)   bq:1261.87  B:0.067   <>:0:00

В данной ситуации на счете клиента закуплена монета WBTC на 942$
а на нашем счете BUSD 1261$

Это нормальное начало для торговли.


Если бы было НАОБОРОТ
b1 b:0.0(0) q:1261.87(1262)   bq:1261.87  B:0.067   <>:0.00
b2 b:0.04441(942) q:74.58(75)   bq:1017.0  B:0.048   <>:0.00
То бот2 будет пытаться за 75$ выкупить 0 монет у бота1 

В этом случае стартуем по другому. В карточке #START открываем строку
# Если начинать с продажи
await _try_sell_buy()  if SB_async else try_sell_buy()

стартуем. 
теперь, первым ходом бот1 будет пытаться купить за 1262$ монеты у бота1 на 942$ 
После старта надо эту строку снова закомментировать
#await _try_sell_buy()  if SB_async else try_sell_buy()



ПРОЦЕСС
-В процессе перекачки контроллирую, чтобы рабочая сумма не превышала 1500$
-Ксли превышает, то на боте2 перекидываю часть в USDT
-Если результат сделки >25$ то Бинанс может забанить. (Результат виден в событиях  <>:32.4) 
Резкое изменение баланса счета Бинанс видит


ОТКЛЮЧЕНИЕ
В торговом файле Нажимаю на restart kernel
Скачиваю файлы с отчетами на сервере в папке Documents\Python Scripts\rep.
