# %% [markdown]
# # Методы

# %% [markdown]
# ## Keys

# %%
#1 кошелек, откуда переливаем

b1_API_KEY='
b1_API_SECRET='' #30.01.23


# кошелек, куда переливаем
    # Нияз личный
b2_API_KEY='u'  # 31.01.23
b2_API_SECRET=''

# загрузка функций
# %run fn.ipynb

# %%
#3 подготовка параметров для торговли  
min_spread_in_percent = 0.55

b = 'HARD'; # 2/10
q = 'BUSD'; u = 'BUSD'



#------------------
Work_usd  = 90 # количество USD для работы
usd_min   = 25
kb = 0.98
#------------------
find_pairs(b, q, u)
coin_bunch = 2
if q == u : busd_busd = True
else      : busd_busd = False
o1={}; o2={}
client_report = ''
isWriteToFile = False
# Out:
# base_quote: HARDBUSD
# base_usd: HARDBUSD True
# usd_quote: BUSDBUSD False

# %%
#4 START

isWriteToFile = True
if isWriteToFile : f = createFile('rep\M40')


BS_async = True
SB_async = True
time_b2_b1 = 0.5

time_wait_spread = 3 #sek
eat_vol = 0.06


cancel_orders(bot2)
get_new_Work_usd()
busd_to_bnb()

#after_sell()

# Если начинать с продажи
#await _try_sell_buy()  if SB_async else try_sell_buy()


#global client_report
step = 1
while 1 :
  print('\n--------------------------------------------------------------------------------')
  print(f'шаг {step}')
  client_report = client_report + f'шаг {step}' + '\n'
  print('\n------------BUY - SELL')

  #is_async if   await try_buy_sell() else try_buy_sell()
  await _try_buy_sell()  if BS_async else try_buy_sell()

  if step % 2 == 1 :
    print('\n------------BUSD_TO_BNB')
    busd_to_bnb()  #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
  if step % 8 == 1 :
    print('\n------------WORK_USD')
    get_new_Work_usd()
  print('\n------------SELL - BUY')

    
  await _try_sell_buy()  if SB_async else try_sell_buy()

  t = random.random() *35 + 5
  print('sleep: ', t)
  time.sleep( t )
  step = step + 1
# Out:
# b1 b:115.043(22) q:1092.43(1092)   bq:1114.28  B:0.065   <>:1114.28
# b2 b:115.0(22) q:1115.00(1115)   bq:1136.84  B:0.024   <>:1136.84
# New W_usd: 1002.86
# b1 b:115.043(22) q:1092.43(1092)   bq:1114.28  B:0.065   <>:0.00
# b2 b:115.0(22) q:1115.00(1115)   bq:1136.84  B:0.024   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# --------------------------------------------------------------------------------
# шаг 1
#
# ------------BUY - SELL
# b1 b:115.043(22) q:1092.43(1092)   bq:1114.28  B:0.065   <>:0.00
# b2 b:115.0(22) q:1115.00(1115)   bq:1136.84  B:0.024   <>:0.00
# HARDBUSD . спрэд: 0.37   ping: 64   bid: 0.19   ask: 0.1907
# HARDBUSD . спрэд: 0.31   ping: 56   bid: 0.1901   ask: 0.1907
# HARDBUSD . спрэд: 0.26   ping: 53   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 44   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.1   ping: 47   bid: 0.1905   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1903   ask: 0.1907
# HARDBUSD . спрэд: 0.26   ping: 61   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 49   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.05   ping: 47   bid: 0.1906   ask: 0.1907
# HARDBUSD . спрэд: 0.1   ping: 48   bid: 0.1906   ask: 0.1908
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1904   ask: 0.1908
# HARDBUSD . спрэд: 0.16   ping: 31   bid: 0.1904   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 52   bid: 0.1903   ask: 0.1907
# HARDBUSD . спрэд: 0.16   ping: 54   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.05   ping: 63   bid: 0.1904   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 30   bid: 0.1904   ask: 0.1907
# HARDBUSD . спрэд: 0.11   ping: 31   bid: 0.1902   ask: 0.1904
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.05   ping: 48   bid: 0.1902   ask: 0.1903
# HARDBUSD . спрэд: 0.1   ping: 40   bid: 0.1904   ask: 0.1906
# HARDBUSD . спрэд: 0.11   ping: 62   bid: 0.19   ask: 0.1902
# HARDBUSD . спрэд: 0.05   ping: 43   bid: 0.1901   ask: 0.1902
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.21   ping: 59   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 33   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.11   ping: 29   bid: 0.1902   ask: 0.1904
# HARDBUSD . спрэд: 0.16   ping: 54   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.11   ping: 53   bid: 0.1902   ask: 0.1904
# HARDBUSD . спрэд: 0.16   ping: 31   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.11   ping: 53   bid: 0.1902   ask: 0.1904
# HARDBUSD . спрэд: 0.16   ping: 41   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.11   ping: 77   bid: 0.1902   ask: 0.1904
# HARDBUSD . спрэд: 0.16   ping: 62   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.11   ping: 48   bid: 0.1902   ask: 0.1904
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.11   ping: 40   bid: 0.1902   ask: 0.1904
# HARDBUSD . спрэд: 0.16   ping: 32   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 31   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 32   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.26   ping: 45   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 49   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 27   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 30   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.21   ping: 50   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 60   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 65   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.1   ping: 31   bid: 0.1903   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 53   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 31   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 32   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 45   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 52   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 64   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 44   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 44   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 42   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 62   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 47   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 45   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 90   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 50   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 32   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 50   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 60   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 43   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 34   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 54   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 27   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 62   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 51   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 48   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 35   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 31   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 61   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 33   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 32   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 45   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 33   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 45   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 42   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 48   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 29   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 30   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 33   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 39   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 44   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 44   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 31   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 32   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 76   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 74   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 37   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 44   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 41   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 33   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 31   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 30   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 32   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 30   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 63   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 46   bid: 0.1902   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 32   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 32   bid: 0.1903   ask: 0.1907
# HARDBUSD . спрэд: 0.16   ping: 31   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 58   bid: 0.1903   ask: 0.1907
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 48   bid: 0.1903   ask: 0.1907
# HARDBUSD . спрэд: 0.16   ping: 43   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 28   bid: 0.1903   ask: 0.1907
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.1   ping: 43   bid: 0.1903   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 38   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 46   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 32   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 29   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 56   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 45   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 44   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 72   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 45   bid: 0.1903   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 44   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 43   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.1   ping: 64   bid: 0.1904   ask: 0.1906
# HARDBUSD . спрэд: 0.05   ping: 48   bid: 0.1904   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 36   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 29   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 65   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 30   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.26   ping: 34   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 31   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 45   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 31   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 53   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.68   ping: 45   bid: 0.1892   ask: 0.1905
# HARDBUSD . спрэд: 0.52   ping: 49   bid: 0.1896   ask: 0.1906
# HARDBUSD . спрэд: 0.58   ping: 33   bid: 0.1895   ask: 0.1906
# qty < usd_min/// -->
# buy_sell() True
#
# b1 b:115.043(22) q:1092.43(1092)   bq:1114.23  B:0.065   <>:-0.05
# b2 b:115.0(22) q:1115.00(1115)   bq:1136.79  B:0.025   <>:-0.05
# b2 base меньше рабочей суммы
# b2 переливаем quote в base 981.068146813
# b2  quote_to_base: HARDBUSD 981.068146813
# HARDBUSD origQty:5136 exQty:5136
#
# ------------BUSD_TO_BNB
# b1 b:115.043(22) q:1092.43(1092)   bq:1114.27  B:0.065   <>:0.04
# b2 b:5251.0(997) q:134.92(135)   bq:1132.08  B:0.023   <>:-4.71
# b1 BNB ok
# b2 BNB ok
#
# ------------WORK_USD
# b1 b:115.043(22) q:1092.43(1092)   bq:1114.28  B:0.065   <>:0.01
# b2 b:5251.0(998) q:134.92(135)   bq:1132.61  B:0.023   <>:0.53
# New W_usd: 1002.86
#
# ------------SELL - BUY
# b1 b:115.043(22) q:1092.43(1092)   bq:1114.28  B:0.065   <>:0.00
# b2 b:5251.0(998) q:134.92(135)   bq:1132.61  B:0.023   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1909 quantity: 5140
# b2 setOrder HARDBUSD origQty:5140 exQty:0
# b1 setOrder HARDBUSD origQty:5140 exQty:5140
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5249.903(997) q:111.21(111)   bq:1108.68  B:0.065   <>:-5.60
# b2 b:111.0(21) q:1116.15(1116)   bq:1137.23  B:0.023   <>:4.62
# sleep:  11.441088127450826
#
# --------------------------------------------------------------------------------
# шаг 2
#
# ------------BUY - SELL
# b1 b:5249.903(999) q:111.21(111)   bq:1109.73  B:0.065   <>:1.05
# b2 b:111.0(21) q:1116.15(1116)   bq:1137.26  B:0.023   <>:0.03
# HARDBUSD . спрэд: 0.37   ping: 49   bid: 0.1902   ask: 0.1909
# HARDBUSD . спрэд: 0.42   ping: 60   bid: 0.1899   ask: 0.1907
# HARDBUSD . спрэд: 0.37   ping: 56   bid: 0.1901   ask: 0.1908
# HARDBUSD . спрэд: 0.26   ping: 68   bid: 0.1901   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1902   ask: 0.1906
# HARDBUSD . спрэд: 0.47   ping: 46   bid: 0.1898   ask: 0.1907
# HARDBUSD . спрэд: 0.37   ping: 31   bid: 0.1898   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 48   bid: 0.19   ask: 0.1904
# HARDBUSD . спрэд: 0.16   ping: 153   bid: 0.1901   ask: 0.1904
# HARDBUSD . спрэд: 0.11   ping: 70   bid: 0.1902   ask: 0.1904
# HARDBUSD . спрэд: 0.31   ping: 58   bid: 0.1902   ask: 0.1908
# HARDBUSD . спрэд: 0.16   ping: 47   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.11   ping: 32   bid: 0.1901   ask: 0.1903
# HARDBUSD . спрэд: 0.26   ping: 52   bid: 0.19   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 49   bid: 0.1901   ask: 0.1905
# HARDBUSD . спрэд: 0.11   ping: 49   bid: 0.1901   ask: 0.1903
# HARDBUSD . спрэд: 0.16   ping: 45   bid: 0.1902   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 41   bid: 0.19   ask: 0.1904
# HARDBUSD . спрэд: 0.26   ping: 78   bid: 0.19   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 48   bid: 0.19   ask: 0.1904
# HARDBUSD . спрэд: 0.42   ping: 67   bid: 0.19   ask: 0.1908
# HARDBUSD . спрэд: 0.31   ping: 49   bid: 0.19   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.19   ask: 0.1904
# HARDBUSD . спрэд: 0.37   ping: 46   bid: 0.1899   ask: 0.1906
# HARDBUSD . спрэд: 0.26   ping: 62   bid: 0.1899   ask: 0.1904
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1899   ask: 0.1903
# HARDBUSD . спрэд: 0.37   ping: 49   bid: 0.1895   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 32   bid: 0.1898   ask: 0.1902
# HARDBUSD . спрэд: 0.26   ping: 65   bid: 0.1895   ask: 0.19
# HARDBUSD . спрэд: 0.42   ping: 32   bid: 0.1895   ask: 0.1903
# HARDBUSD . спрэд: 0.37   ping: 54   bid: 0.1896   ask: 0.1903
# HARDBUSD . спрэд: 0.26   ping: 31   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.21   ping: 45   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.26   ping: 28   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.42   ping: 36   bid: 0.1896   ask: 0.1904
# HARDBUSD . спрэд: 0.32   ping: 45   bid: 0.1896   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 45   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.26   ping: 12   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.21   ping: 49   bid: 0.1897   ask: 0.1901
# HARDBUSD . спрэд: 0.47   ping: 48   bid: 0.1897   ask: 0.1906
# HARDBUSD . спрэд: 0.32   ping: 38   bid: 0.1897   ask: 0.1903
# HARDBUSD . спрэд: 0.26   ping: 48   bid: 0.1897   ask: 0.1902
# HARDBUSD . спрэд: 0.32   ping: 51   bid: 0.1896   ask: 0.1902
# HARDBUSD . спрэд: 0.26   ping: 50   bid: 0.1897   ask: 0.1902
# HARDBUSD . спрэд: 0.37   ping: 52   bid: 0.1895   ask: 0.1902
# HARDBUSD . спрэд: 0.26   ping: 30   bid: 0.1897   ask: 0.1902
# HARDBUSD . спрэд: 0.37   ping: 51   bid: 0.1895   ask: 0.1902
# HARDBUSD . спрэд: 0.42   ping: 47   bid: 0.1895   ask: 0.1903
# HARDBUSD . спрэд: 0.37   ping: 61   bid: 0.1895   ask: 0.1902
# HARDBUSD . спрэд: 0.47   ping: 62   bid: 0.1895   ask: 0.1904
# HARDBUSD . спрэд: 0.26   ping: 48   bid: 0.1895   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1895   ask: 0.1899
# HARDBUSD . спрэд: 0.26   ping: 59   bid: 0.1895   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 45   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.26   ping: 31   bid: 0.1895   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 24   bid: 0.1895   ask: 0.1899
# HARDBUSD . спрэд: 0.26   ping: 32   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.26   ping: 64   bid: 0.1895   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.26   ping: 31   bid: 0.1895   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.47   ping: 32   bid: 0.189   ask: 0.1899
# HARDBUSD . спрэд: 0.05   ping: 28   bid: 0.1889   ask: 0.189
# HARDBUSD . спрэд: 0.58   ping: 54   bid: 0.1889   ask: 0.19
# b2 BUY  HARDBUSD price_dwn: 0.189 quantity: 5139
# bot1 try SELL  5139
# b2 setOrder HARDBUSD origQty:5139 exQty:0
# b1 setOrder HARDBUSD origQty:5139 exQty:5139
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b1 b:110.903(21) q:1081.51(1082)   bq:1102.45  B:0.065   <>:-7.28
# b2 b:5250.0(992) q:144.88(145)   bq:1136.6  B:0.023   <>:-0.66
#
# ------------SELL - BUY
# b1 b:110.903(21) q:1081.51(1082)   bq:1102.45  B:0.065   <>:0.00
# b2 b:5250.0(992) q:144.88(145)   bq:1136.6  B:0.023   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1898 quantity: 5139
# b2 setOrder HARDBUSD origQty:5139 exQty:0
# b1 setOrder HARDBUSD origQty:5139 exQty:5139
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b2 oo0 закрыл остатки HARDBUSD origQty:5139 exQty:1860
# b1 b:5244.764(990) q:106.45(106)   bq:1096.66  B:0.065   <>:-5.79
# b2 b:3390.0(640) q:497.91(498)   bq:1137.93  B:0.023   <>:1.33
# b2 quote меньше рабочей суммы
# b2 переливаем base в quote 2663.2671245411393
# b2  base_to_quote: HARDBUSD 2663.2671245411393
# HARDBUSD origQty:2661 exQty:2661
# sleep:  7.7543649652150295
#
# --------------------------------------------------------------------------------
# шаг 3
#
# ------------BUY - SELL
# b1 b:5244.764(990) q:106.45(106)   bq:1096.66  B:0.065   <>:0.00
# b2 b:729.0(138) q:999.98(1000)   bq:1137.61  B:0.022   <>:-0.32
# HARDBUSD . спрэд: 0.26   ping: 45   bid: 0.1888   ask: 0.1893
# HARDBUSD . спрэд: 0.32   ping: 48   bid: 0.1887   ask: 0.1893
# HARDBUSD . спрэд: 0.26   ping: 45   bid: 0.1888   ask: 0.1893
# HARDBUSD . спрэд: 0.21   ping: 56   bid: 0.1889   ask: 0.1893
# HARDBUSD . спрэд: 0.63   ping: 78   bid: 0.1887   ask: 0.1899
# HARDBUSD . спрэд: 0.53   ping: 46   bid: 0.1888   ask: 0.1898
# HARDBUSD . спрэд: 0.42   ping: 64   bid: 0.189   ask: 0.1898
# HARDBUSD . спрэд: 0.47   ping: 35   bid: 0.189   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 29   bid: 0.1891   ask: 0.1899
# HARDBUSD . спрэд: 0.47   ping: 62   bid: 0.189   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 25   bid: 0.1891   ask: 0.1899
# HARDBUSD . спрэд: 0.47   ping: 59   bid: 0.189   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 30   bid: 0.1891   ask: 0.1899
# HARDBUSD . спрэд: 0.47   ping: 44   bid: 0.189   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 30   bid: 0.1891   ask: 0.1899
# HARDBUSD . спрэд: 0.53   ping: 51   bid: 0.1889   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 31   bid: 0.1891   ask: 0.1899
# HARDBUSD . спрэд: 0.53   ping: 67   bid: 0.1889   ask: 0.1899
# HARDBUSD . спрэд: 0.47   ping: 16   bid: 0.189   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 31   bid: 0.1891   ask: 0.1898
# HARDBUSD . спрэд: 0.32   ping: 53   bid: 0.1892   ask: 0.1898
# HARDBUSD . спрэд: 0.26   ping: 81   bid: 0.1893   ask: 0.1898
# HARDBUSD . спрэд: 0.32   ping: 47   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.26   ping: 40   bid: 0.1894   ask: 0.1899
# HARDBUSD . спрэд: 0.32   ping: 33   bid: 0.1894   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 33   bid: 0.1895   ask: 0.1899
# HARDBUSD . спрэд: 0.26   ping: 41   bid: 0.1894   ask: 0.1899
# HARDBUSD . спрэд: 0.32   ping: 47   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.26   ping: 64   bid: 0.1894   ask: 0.1899
# HARDBUSD . спрэд: 0.32   ping: 32   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 48   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 45   bid: 0.1894   ask: 0.19
# HARDBUSD . спрэд: 0.37   ping: 33   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.26   ping: 33   bid: 0.1893   ask: 0.1898
# HARDBUSD . спрэд: 0.37   ping: 61   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 31   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 38   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 48   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 44   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 45   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 54   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 43   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 28   bid: 0.1892   ask: 0.1899
# HARDBUSD . спрэд: 0.32   ping: 30   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 62   bid: 0.1892   ask: 0.1899
# HARDBUSD . спрэд: 0.32   ping: 45   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 35   bid: 0.1892   ask: 0.1899
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1889   ask: 0.1892
# HARDBUSD . спрэд: 0.11   ping: 32   bid: 0.189   ask: 0.1892
# HARDBUSD . спрэд: 0.05   ping: 56   bid: 0.1891   ask: 0.1892
# HARDBUSD . спрэд: 0.32   ping: 18   bid: 0.1892   ask: 0.1898
# HARDBUSD . спрэд: 0.37   ping: 55   bid: 0.1891   ask: 0.1898
# HARDBUSD . спрэд: 0.42   ping: 47   bid: 0.189   ask: 0.1898
# HARDBUSD . спрэд: 0.37   ping: 41   bid: 0.1891   ask: 0.1898
# HARDBUSD . спрэд: 0.32   ping: 41   bid: 0.1892   ask: 0.1898
# HARDBUSD . спрэд: 0.26   ping: 61   bid: 0.1893   ask: 0.1898
# HARDBUSD . спрэд: 0.37   ping: 61   bid: 0.1891   ask: 0.1898
# HARDBUSD . спрэд: 0.32   ping: 81   bid: 0.1892   ask: 0.1898
# HARDBUSD . спрэд: 0.26   ping: 51   bid: 0.1893   ask: 0.1898
# HARDBUSD . спрэд: 0.21   ping: 49   bid: 0.1893   ask: 0.1897
# HARDBUSD . спрэд: 0.26   ping: 62   bid: 0.1893   ask: 0.1898
# HARDBUSD . спрэд: 0.21   ping: 48   bid: 0.1893   ask: 0.1897
# HARDBUSD . спрэд: 0.37   ping: 63   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 47   bid: 0.1894   ask: 0.19
# HARDBUSD . спрэд: 0.37   ping: 45   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 62   bid: 0.1894   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 63   bid: 0.1894   ask: 0.1898
# HARDBUSD . спрэд: 0.26   ping: 57   bid: 0.1893   ask: 0.1898
# HARDBUSD . спрэд: 0.32   ping: 31   bid: 0.1894   ask: 0.19
# HARDBUSD . спрэд: 0.37   ping: 46   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 63   bid: 0.1894   ask: 0.19
# HARDBUSD . спрэд: 0.26   ping: 35   bid: 0.1894   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 46   bid: 0.1892   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 56   bid: 0.1892   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 44   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.47   ping: 25   bid: 0.189   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 33   bid: 0.1891   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 60   bid: 0.1892   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 39   bid: 0.1891   ask: 0.1899
# HARDBUSD . спрэд: 0.47   ping: 36   bid: 0.1891   ask: 0.19
# HARDBUSD . спрэд: 0.42   ping: 34   bid: 0.1892   ask: 0.19
# HARDBUSD . спрэд: 0.47   ping: 50   bid: 0.1891   ask: 0.19
# HARDBUSD . спрэд: 0.37   ping: 46   bid: 0.1892   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 43   bid: 0.1892   ask: 0.19
# HARDBUSD . спрэд: 0.37   ping: 73   bid: 0.1892   ask: 0.1899
# HARDBUSD . спрэд: 0.42   ping: 63   bid: 0.1892   ask: 0.19
# HARDBUSD . спрэд: 0.47   ping: 104   bid: 0.1892   ask: 0.1901
# HARDBUSD . спрэд: 0.42   ping: 50   bid: 0.1892   ask: 0.19
# HARDBUSD . спрэд: 0.47   ping: 47   bid: 0.1892   ask: 0.1901
# HARDBUSD . спрэд: 0.42   ping: 45   bid: 0.1893   ask: 0.1901
# HARDBUSD . спрэд: 0.47   ping: 46   bid: 0.1892   ask: 0.1901
# HARDBUSD . спрэд: 0.26   ping: 45   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.37   ping: 28   bid: 0.1894   ask: 0.1901
# HARDBUSD . спрэд: 0.32   ping: 52   bid: 0.1895   ask: 0.1901
# HARDBUSD . спрэд: 0.37   ping: 54   bid: 0.1894   ask: 0.1901
# HARDBUSD . спрэд: 0.32   ping: 29   bid: 0.1895   ask: 0.1901
# HARDBUSD . спрэд: 0.37   ping: 94   bid: 0.1894   ask: 0.1901
# HARDBUSD . спрэд: 0.32   ping: 30   bid: 0.1895   ask: 0.1901
# HARDBUSD . спрэд: 0.37   ping: 30   bid: 0.1894   ask: 0.1901
# HARDBUSD . спрэд: 0.32   ping: 59   bid: 0.1895   ask: 0.1901
# HARDBUSD . спрэд: 0.37   ping: 32   bid: 0.1894   ask: 0.1901
# HARDBUSD . спрэд: 0.32   ping: 47   bid: 0.1895   ask: 0.1901
# HARDBUSD . спрэд: 0.37   ping: 25   bid: 0.1894   ask: 0.1901
# HARDBUSD . спрэд: 0.32   ping: 45   bid: 0.1895   ask: 0.1901
# HARDBUSD . спрэд: 0.26   ping: 56   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.11   ping: 46   bid: 0.1899   ask: 0.1901
# HARDBUSD . спрэд: 0.47   ping: 61   bid: 0.1899   ask: 0.1908
# HARDBUSD . спрэд: 0.42   ping: 48   bid: 0.19   ask: 0.1908
# HARDBUSD . спрэд: 0.37   ping: 54   bid: 0.19   ask: 0.1907
# HARDBUSD . спрэд: 0.47   ping: 62   bid: 0.19   ask: 0.1909
# HARDBUSD . спрэд: 0.42   ping: 48   bid: 0.19   ask: 0.1908
# HARDBUSD . спрэд: 0.37   ping: 45   bid: 0.1901   ask: 0.1908
# HARDBUSD . спрэд: 0.42   ping: 33   bid: 0.19   ask: 0.1908
# HARDBUSD . спрэд: 0.37   ping: 47   bid: 0.1901   ask: 0.1908
# HARDBUSD . спрэд: 0.47   ping: 47   bid: 0.19   ask: 0.1909
# HARDBUSD . спрэд: 0.37   ping: 64   bid: 0.1902   ask: 0.1909
# HARDBUSD . спрэд: 0.47   ping: 44   bid: 0.19   ask: 0.1909
# HARDBUSD . спрэд: 0.37   ping: 49   bid: 0.1902   ask: 0.1909
# HARDBUSD . спрэд: 0.47   ping: 50   bid: 0.19   ask: 0.1909
# HARDBUSD . спрэд: 0.37   ping: 48   bid: 0.1902   ask: 0.1909
# HARDBUSD . спрэд: 0.31   ping: 48   bid: 0.1903   ask: 0.1909
# HARDBUSD . спрэд: 0.42   ping: 48   bid: 0.1903   ask: 0.1911
# HARDBUSD . спрэд: 0.37   ping: 31   bid: 0.1903   ask: 0.191
# HARDBUSD . спрэд: 0.31   ping: 35   bid: 0.1904   ask: 0.191
# HARDBUSD . спрэд: 0.37   ping: 46   bid: 0.1904   ask: 0.1911
# HARDBUSD . спрэд: 0.42   ping: 62   bid: 0.1903   ask: 0.1911
# HARDBUSD . спрэд: 0.52   ping: 47   bid: 0.1901   ask: 0.1911
# HARDBUSD . спрэд: 0.47   ping: 31   bid: 0.1902   ask: 0.1911
# HARDBUSD . спрэд: 0.42   ping: 50   bid: 0.1902   ask: 0.191
# HARDBUSD . спрэд: 0.68   ping: 37   bid: 0.1896   ask: 0.1909
# b2 BUY  HARDBUSD price_dwn: 0.1897 quantity: 5134
# bot1 try SELL  5134
# b2 setOrder HARDBUSD origQty:5134 exQty:0
# b1 setOrder HARDBUSD origQty:5134 exQty:5134
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b1 b:110.764(21) q:1079.40(1079)   bq:1100.39  B:0.065   <>:3.73
# b2 b:5863.0(1112) q:26.06(26)   bq:1137.68  B:0.024   <>:0.07
#
# ------------BUSD_TO_BNB
# b1 b:110.764(21) q:1079.40(1079)   bq:1100.4  B:0.065   <>:0.01
# b2 b:5863.0(1112) q:26.06(26)   bq:1138.27  B:0.024   <>:0.59
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:110.764(21) q:1079.40(1079)   bq:1100.4  B:0.065   <>:0.00
# b2 b:5863.0(1112) q:26.06(26)   bq:1138.27  B:0.024   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1907 quantity: 5567
# b2 setOrder HARDBUSD origQty:5567 exQty:0
# b1 setOrder HARDBUSD origQty:5567 exQty:5567
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b2 oo0 закрыл остатки HARDBUSD origQty:5567 exQty:4518
# b1 b:5672.197(1077) q:17.87(18)   bq:1094.45  B:0.065   <>:-5.95
# b2 b:1345.0(255) q:887.64(888)   bq:1142.92  B:0.024   <>:4.65
# b2 quote меньше рабочей суммы
# b2 переливаем base в quote 603.226423104712
# b2  base_to_quote: HARDBUSD 603.226423104712
# HARDBUSD origQty:603 exQty:603
# sleep:  35.18553683156452
#
# --------------------------------------------------------------------------------
# шаг 4
#
# ------------BUY - SELL
# b1 b:5672.197(1077) q:17.87(18)   bq:1095.02  B:0.065   <>:0.57
# b2 b:742.0(141) q:1001.91(1002)   bq:1142.81  B:0.024   <>:-0.11
# HARDBUSD . спрэд: 0.26   ping: 51   bid: 0.1899   ask: 0.1904
# HARDBUSD . спрэд: 0.73   ping: 60   bid: 0.1892   ask: 0.1906
# HARDBUSD . спрэд: 0.32   ping: 49   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.21   ping: 59   bid: 0.1893   ask: 0.1897
# HARDBUSD . спрэд: 0.26   ping: 46   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.16   ping: 48   bid: 0.1896   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 61   bid: 0.1896   ask: 0.1903
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 47   bid: 0.1896   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 30   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.16   ping: 57   bid: 0.1896   ask: 0.1899
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.11   ping: 31   bid: 0.1896   ask: 0.1898
# HARDBUSD . спрэд: 0.32   ping: 46   bid: 0.1897   ask: 0.1903
# HARDBUSD . спрэд: 0.26   ping: 15   bid: 0.1897   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1898   ask: 0.1902
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1898   ask: 0.1903
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1898   ask: 0.1902
# HARDBUSD . спрэд: 0.47   ping: 35   bid: 0.1898   ask: 0.1907
# HARDBUSD . спрэд: 0.42   ping: 42   bid: 0.1898   ask: 0.1906
# HARDBUSD . спрэд: 0.47   ping: 52   bid: 0.1898   ask: 0.1907
# HARDBUSD . спрэд: 0.31   ping: 34   bid: 0.1899   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 39   bid: 0.1899   ask: 0.1903
# HARDBUSD . спрэд: 0.16   ping: 36   bid: 0.1899   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1899   ask: 0.1903
# HARDBUSD . спрэд: 0.16   ping: 56   bid: 0.1899   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 58   bid: 0.1899   ask: 0.1903
# HARDBUSD . спрэд: 0.16   ping: 45   bid: 0.1899   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1899   ask: 0.1903
# HARDBUSD . спрэд: 0.16   ping: 47   bid: 0.1899   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 37   bid: 0.1898   ask: 0.1902
# HARDBUSD . спрэд: 0.16   ping: 31   bid: 0.1899   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 37   bid: 0.1898   ask: 0.1902
# HARDBUSD . спрэд: 0.42   ping: 63   bid: 0.1899   ask: 0.1907
# HARDBUSD . спрэд: 0.31   ping: 46   bid: 0.1899   ask: 0.1905
# HARDBUSD . спрэд: 0.42   ping: 46   bid: 0.1899   ask: 0.1907
# HARDBUSD . спрэд: 0.31   ping: 28   bid: 0.1899   ask: 0.1905
# HARDBUSD . спрэд: 0.42   ping: 47   bid: 0.1899   ask: 0.1907
# HARDBUSD . спрэд: 0.47   ping: 36   bid: 0.1898   ask: 0.1907
# HARDBUSD . спрэд: 0.26   ping: 57   bid: 0.1899   ask: 0.1904
# HARDBUSD . спрэд: 0.21   ping: 37   bid: 0.1899   ask: 0.1903
# HARDBUSD . спрэд: 0.26   ping: 78   bid: 0.1899   ask: 0.1904
# HARDBUSD . спрэд: 0.21   ping: 44   bid: 0.19   ask: 0.1904
# HARDBUSD . спрэд: 0.26   ping: 44   bid: 0.1898   ask: 0.1903
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1899   ask: 0.1903
# HARDBUSD . спрэд: 0.42   ping: 41   bid: 0.1899   ask: 0.1907
# HARDBUSD . спрэд: 0.37   ping: 31   bid: 0.1899   ask: 0.1906
# HARDBUSD . спрэд: 0.42   ping: 42   bid: 0.1899   ask: 0.1907
# HARDBUSD . спрэд: 0.47   ping: 40   bid: 0.1898   ask: 0.1907
# HARDBUSD . спрэд: 0.42   ping: 16   bid: 0.1898   ask: 0.1906
# HARDBUSD . спрэд: 0.47   ping: 50   bid: 0.1898   ask: 0.1907
# HARDBUSD . спрэд: 0.42   ping: 40   bid: 0.1898   ask: 0.1906
# HARDBUSD . спрэд: 0.47   ping: 41   bid: 0.1898   ask: 0.1907
# HARDBUSD . спрэд: 0.26   ping: 32   bid: 0.1898   ask: 0.1903
# HARDBUSD . спрэд: 0.47   ping: 53   bid: 0.1898   ask: 0.1907
# HARDBUSD . спрэд: 0.37   ping: 61   bid: 0.1898   ask: 0.1905
# HARDBUSD . спрэд: 0.31   ping: 48   bid: 0.1899   ask: 0.1905
# HARDBUSD . спрэд: 0.37   ping: 72   bid: 0.1899   ask: 0.1906
# HARDBUSD . спрэд: 0.31   ping: 93   bid: 0.1899   ask: 0.1905
# HARDBUSD . спрэд: 0.42   ping: 88   bid: 0.1898   ask: 0.1906
# HARDBUSD . спрэд: 0.37   ping: 91   bid: 0.1898   ask: 0.1905
# HARDBUSD . спрэд: 0.32   ping: 93   bid: 0.1898   ask: 0.1904
# HARDBUSD . спрэд: 0.42   ping: 65   bid: 0.1898   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 104   bid: 0.1895   ask: 0.1898
# HARDBUSD . спрэд: 0.58   ping: 110   bid: 0.1895   ask: 0.1906
# b2 BUY  HARDBUSD price_dwn: 0.1896 quantity: 5165
# bot1 try SELL  5165
# b2 setOrder HARDBUSD origQty:5165 exQty:0
# b1 setOrder HARDBUSD origQty:5165 exQty:5165
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b1 b:507.197(96) q:996.18(996)   bq:1092.24  B:0.065   <>:-2.78
# b2 b:5907.0(1119) q:22.63(23)   bq:1141.41  B:0.026   <>:-1.40
#
# ------------SELL - BUY
# b1 b:507.197(96) q:996.18(996)   bq:1092.24  B:0.065   <>:0.00
# b2 b:5907.0(1119) q:22.63(23)   bq:1141.41  B:0.026   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1904 quantity: 5149
# b2 setOrder HARDBUSD origQty:5149 exQty:0
# b1 setOrder HARDBUSD origQty:5149 exQty:5149
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5651.048(1071) q:15.81(16)   bq:1086.68  B:0.065   <>:-5.56
# b2 b:758.0(144) q:1003.00(1003)   bq:1146.63  B:0.026   <>:5.22
# sleep:  22.140310457816398
#
# --------------------------------------------------------------------------------
# шаг 5
#
# ------------BUY - SELL
# b1 b:5651.048(1072) q:15.81(16)   bq:1087.81  B:0.065   <>:1.13
# b2 b:758.0(144) q:1003.00(1003)   bq:1146.79  B:0.026   <>:0.16
# HARDBUSD . спрэд: 0.37   ping: 74   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.47   ping: 67   bid: 0.1895   ask: 0.1904
# HARDBUSD . спрэд: 0.42   ping: 139   bid: 0.1895   ask: 0.1903
# HARDBUSD . спрэд: 0.37   ping: 70   bid: 0.1896   ask: 0.1903
# HARDBUSD . спрэд: 0.26   ping: 57   bid: 0.1896   ask: 0.1901
# HARDBUSD . спрэд: 0.21   ping: 63   bid: 0.1897   ask: 0.1901
# HARDBUSD . спрэд: 0.32   ping: 68   bid: 0.1895   ask: 0.1901
# HARDBUSD . спрэд: 0.37   ping: 64   bid: 0.1895   ask: 0.1902
# HARDBUSD . спрэд: 0.42   ping: 84   bid: 0.1892   ask: 0.19
# HARDBUSD . спрэд: 0.37   ping: 113   bid: 0.1892   ask: 0.1899
# HARDBUSD . спрэд: 0.53   ping: 122   bid: 0.1892   ask: 0.1902
# HARDBUSD . спрэд: 0.42   ping: 85   bid: 0.1892   ask: 0.19
# HARDBUSD . спрэд: 0.53   ping: 115   bid: 0.1892   ask: 0.1902
# HARDBUSD . спрэд: 0.47   ping: 111   bid: 0.1892   ask: 0.1901
# HARDBUSD . спрэд: 0.37   ping: 56   bid: 0.189   ask: 0.1897
# HARDBUSD . спрэд: 0.26   ping: 79   bid: 0.1892   ask: 0.1897
# HARDBUSD . спрэд: 0.58   ping: 75   bid: 0.1892   ask: 0.1903
# HARDBUSD . спрэд: 0.21   ping: 70   bid: 0.1892   ask: 0.1896
# HARDBUSD . спрэд: 0.63   ping: 69   bid: 0.1884   ask: 0.1896
# HARDBUSD . спрэд: 0.47   ping: 93   bid: 0.1887   ask: 0.1896
# HARDBUSD . спрэд: 0.63   ping: 44   bid: 0.1887   ask: 0.1899
# b2 BUY  HARDBUSD price_dwn: 0.1888 quantity: 5176
# bot1 try SELL  5176
# b2 setOrder HARDBUSD origQty:5176 exQty:0
# b1 setOrder HARDBUSD origQty:5176 exQty:5176
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b2 oo0 закрыл остатки HARDBUSD origQty:5176 exQty:4118
# b1 b:475.048(89) q:992.17(992)   bq:1081.66  B:0.065   <>:-6.15
# b2 b:4876.0(919) q:225.52(226)   bq:1144.15  B:0.026   <>:-2.64
# b2 base меньше рабочей суммы
# b2 переливаем quote в base 84.70984681300001
# b2  quote_to_base: HARDBUSD 84.70984681300001
# HARDBUSD origQty:444 exQty:444
#
# ------------BUSD_TO_BNB
# b1 b:475.048(90) q:992.17(992)   bq:1081.71  B:0.065   <>:0.05
# b2 b:5320.0(1003) q:141.07(141)   bq:1143.89  B:0.025   <>:-0.26
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:475.048(90) q:992.17(992)   bq:1081.76  B:0.065   <>:0.05
# b2 b:5320.0(1003) q:141.07(141)   bq:1144.42  B:0.025   <>:0.53
# b2 SELL  HARDBUSD price_up: 0.1895 quantity: 5153
# b2 setOrder HARDBUSD origQty:5153 exQty:0
# b1 setOrder HARDBUSD origQty:5153 exQty:5153
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5622.895(1059) q:15.67(16)   bq:1075.02  B:0.065   <>:-6.74
# b2 b:167.0(31) q:1117.56(1118)   bq:1149.02  B:0.025   <>:4.60
# sleep:  11.759942190286
#
# --------------------------------------------------------------------------------
# шаг 6
#
# ------------BUY - SELL
# b1 b:5622.895(1062) q:15.67(16)   bq:1077.83  B:0.065   <>:2.81
# b2 b:167.0(32) q:1117.56(1118)   bq:1149.11  B:0.025   <>:0.09
# HARDBUSD . спрэд: 0.32   ping: 66   bid: 0.189   ask: 0.1896
# HARDBUSD . спрэд: 0.37   ping: 72   bid: 0.1889   ask: 0.1896
# HARDBUSD . спрэд: 0.84   ping: 126   bid: 0.1883   ask: 0.1899
# b2 BUY  HARDBUSD price_dwn: 0.1884 quantity: 5504
# bot1 try SELL  5504
# b2 setOrder HARDBUSD origQty:5504 exQty:0
# b1 setOrder HARDBUSD origQty:5504 exQty:5504
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b2 oo0 закрыл остатки HARDBUSD origQty:5504 exQty:4991
# b1 b:118.895(22) q:1051.65(1052)   bq:1074.04  B:0.065   <>:-3.79
# b2 b:5158.0(971) q:177.26(177)   bq:1148.51  B:0.025   <>:-0.60
#
# ------------SELL - BUY
# b1 b:118.895(22) q:1051.65(1052)   bq:1074.05  B:0.065   <>:0.01
# b2 b:5158.0(972) q:177.26(177)   bq:1149.02  B:0.025   <>:0.51
# b2 SELL  HARDBUSD price_up: 0.1897 quantity: 5049
# b2 setOrder HARDBUSD origQty:5049 exQty:0
# b1 setOrder HARDBUSD origQty:5049 exQty:5049
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5162.846(973) q:93.86(94)   bq:1066.53  B:0.065   <>:-7.52
# b2 b:109.0(21) q:1135.06(1135)   bq:1155.59  B:0.025   <>:6.57
# sleep:  11.32718659962988
#
# --------------------------------------------------------------------------------
# шаг 7
#
# ------------BUY - SELL
# b1 b:5162.846(974) q:93.86(94)   bq:1067.57  B:0.065   <>:1.04
# b2 b:109.0(21) q:1135.06(1135)   bq:1155.61  B:0.025   <>:0.02
# HARDBUSD . спрэд: 0.53   ping: 80   bid: 0.1886   ask: 0.1896
# HARDBUSD . спрэд: 0.42   ping: 88   bid: 0.1887   ask: 0.1895
# HARDBUSD . спрэд: 0.63   ping: 97   bid: 0.1887   ask: 0.1899
# b2 BUY  HARDBUSD price_dwn: 0.1888 quantity: 5054
# bot1 try SELL  5054
# b2 setOrder HARDBUSD origQty:5054 exQty:0
# b1 setOrder HARDBUSD origQty:5054 exQty:5054
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b1 b:108.846(21) q:1047.10(1047)   bq:1067.62  B:0.065   <>:0.05
# b2 b:5163.0(974) q:180.86(181)   bq:1154.6  B:0.025   <>:-1.01
#
# ------------BUSD_TO_BNB
# b1 b:108.846(21) q:1047.10(1047)   bq:1067.62  B:0.065   <>:0.00
# b2 b:5163.0(974) q:180.86(181)   bq:1154.6  B:0.025   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:108.846(21) q:1047.10(1047)   bq:1067.62  B:0.065   <>:0.00
# b2 b:5163.0(974) q:180.86(181)   bq:1154.6  B:0.025   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1897 quantity: 5054
# b2 setOrder HARDBUSD origQty:5054 exQty:0
# b1 setOrder HARDBUSD origQty:5054 exQty:5054
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b2 oo0 закрыл остатки HARDBUSD origQty:5054 exQty:3436
# b1 b:5157.792(974) q:88.52(89)   bq:1062.82  B:0.065   <>:-4.80
# b2 b:1727.0(326) q:832.67(833)   bq:1158.9  B:0.025   <>:4.30
# b2 quote меньше рабочей суммы
# b2 переливаем base в quote 897.6315760179323
# b2  base_to_quote: HARDBUSD 897.6315760179323
# HARDBUSD origQty:897 exQty:897
# sleep:  24.749660766763146
#
# --------------------------------------------------------------------------------
# шаг 8
#
# ------------BUY - SELL
# b1 b:5157.792(972) q:88.52(89)   bq:1060.76  B:0.065   <>:-2.06
# b2 b:830.0(156) q:1002.02(1002)   bq:1158.47  B:0.025   <>:-0.43
# HARDBUSD . спрэд: 0.58   ping: 60   bid: 0.1885   ask: 0.1896
# b2 BUY  HARDBUSD price_dwn: 0.1886 quantity: 5049
# bot1 try SELL  5049
# b2 setOrder HARDBUSD origQty:5049 exQty:0
# b1 setOrder HARDBUSD origQty:5049 exQty:5049
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b1 b:108.792(20) q:1039.81(1040)   bq:1060.3  B:0.065   <>:-0.46
# b2 b:5879.0(1108) q:49.78(50)   bq:1157.38  B:0.025   <>:-1.09
#
# ------------SELL - BUY
# b1 b:108.792(20) q:1039.81(1040)   bq:1060.3  B:0.065   <>:0.00
# b2 b:5879.0(1108) q:49.78(50)   bq:1157.38  B:0.025   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1894 quantity: 5403
# b2 setOrder HARDBUSD origQty:5403 exQty:0
# b1 setOrder HARDBUSD origQty:5403 exQty:5403
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5506.389(1037) q:16.48(16)   bq:1053.88  B:0.065   <>:-6.42
# b2 b:476.0(90) q:1073.11(1073)   bq:1162.78  B:0.025   <>:5.40
# sleep:  6.87822131273556
#
# --------------------------------------------------------------------------------
# шаг 9
#
# ------------BUY - SELL
# b1 b:5506.389(1039) q:16.48(16)   bq:1054.98  B:0.065   <>:1.10
# b2 b:476.0(90) q:1073.11(1073)   bq:1162.88  B:0.025   <>:0.10
# HARDBUSD . спрэд: 0.79   ping: 70   bid: 0.1886   ask: 0.1901
# b2 BUY  HARDBUSD price_dwn: 0.1887 quantity: 5390
# bot1 try SELL  5390
# b2 setOrder HARDBUSD origQty:5390 exQty:0
# b1 setOrder HARDBUSD origQty:5390 exQty:5390
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b1 b:116.389(22) q:1032.55(1033)   bq:1054.47  B:0.065   <>:-0.51
# b2 b:5866.0(1105) q:56.02(56)   bq:1160.58  B:0.025   <>:-2.30
#
# ------------BUSD_TO_BNB
# b1 b:116.389(22) q:1032.55(1033)   bq:1054.47  B:0.065   <>:0.00
# b2 b:5866.0(1105) q:56.02(56)   bq:1160.58  B:0.025   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------WORK_USD
# b1 b:116.389(22) q:1032.55(1033)   bq:1054.47  B:0.065   <>:0.00
# b2 b:5866.0(1105) q:56.02(56)   bq:1160.58  B:0.025   <>:0.00
# New W_usd: 949.02
#
# ------------SELL - BUY
# b1 b:116.389(22) q:1032.55(1033)   bq:1054.47  B:0.065   <>:0.00
# b2 b:5866.0(1105) q:56.02(56)   bq:1160.58  B:0.025   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1896 quantity: 5368
# b2 setOrder HARDBUSD origQty:5368 exQty:0
# b1 setOrder HARDBUSD origQty:5368 exQty:5368
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b2 oo0 закрыл остатки HARDBUSD origQty:5368 exQty:4719
# b1 b:5479.021(1033) q:14.83(15)   bq:1047.62  B:0.065   <>:-6.85
# b2 b:1147.0(216) q:950.74(951)   bq:1166.94  B:0.025   <>:6.36
# sleep:  16.908100722587662
#
# --------------------------------------------------------------------------------
# шаг 10
#
# ------------BUY - SELL
# b1 b:5479.021(1036) q:14.83(15)   bq:1050.36  B:0.065   <>:2.74
# b2 b:1147.0(217) q:950.74(951)   bq:1167.52  B:0.025   <>:0.58
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.189   ask: 0.1895
# HARDBUSD . спрэд: 0.63   ping: 71   bid: 0.189   ask: 0.1902
# b2 BUY  HARDBUSD price_dwn: 0.1891 quantity: 4924
# bot1 try SELL  4924
# b2 setOrder HARDBUSD origQty:4924 exQty:0
# b1 setOrder HARDBUSD origQty:4924 exQty:4924
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b2 oo0 закрыл остатки HARDBUSD origQty:4924 exQty:4788
# b1 b:555.021(105) q:945.04(945)   bq:1049.99  B:0.065   <>:-0.37
# b2 b:5935.0(1122) q:45.33(45)   bq:1167.63  B:0.025   <>:0.11
#
# ------------SELL - BUY
# b1 b:555.021(105) q:945.04(945)   bq:1049.99  B:0.065   <>:0.00
# b2 b:5935.0(1122) q:45.33(45)   bq:1167.63  B:0.025   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1899 quantity: 4892
# b2 setOrder HARDBUSD origQty:4892 exQty:0
# b1 setOrder HARDBUSD origQty:4892 exQty:4892
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5442.129(1029) q:16.05(16)   bq:1045.16  B:0.065   <>:-4.83
# b2 b:1043.0(197) q:974.32(974)   bq:1171.55  B:0.025   <>:3.92
# sleep:  22.76936163631584
#
# --------------------------------------------------------------------------------
# шаг 11
#
# ------------BUY - SELL
# b1 b:5442.129(1030) q:16.05(16)   bq:1045.7  B:0.065   <>:0.54
# b2 b:1043.0(197) q:974.32(974)   bq:1171.65  B:0.025   <>:0.10
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1892   ask: 0.1896
# HARDBUSD . спрэд: 0.26   ping: 44   bid: 0.1892   ask: 0.1897
# HARDBUSD . спрэд: 0.16   ping: 53   bid: 0.1891   ask: 0.1894
# HARDBUSD . спрэд: 0.21   ping: 37   bid: 0.1892   ask: 0.1896
# HARDBUSD . спрэд: 0.26   ping: 30   bid: 0.1891   ask: 0.1896
# HARDBUSD . спрэд: 0.21   ping: 35   bid: 0.1891   ask: 0.1895
# HARDBUSD . спрэд: 0.79   ping: 58   bid: 0.1885   ask: 0.19
# HARDBUSD . спрэд: 0.42   ping: 61   bid: 0.1889   ask: 0.1897
# HARDBUSD . спрэд: 0.58   ping: 51   bid: 0.1889   ask: 0.19
# b2 BUY  HARDBUSD price_dwn: 0.189 quantity: 5041
# bot1 try SELL  5041
# b2 setOrder HARDBUSD origQty:5041 exQty:0
# b1 setOrder HARDBUSD origQty:5041 exQty:5041
# b1 Откуп SELL = FILLED
# buy_sell() True
# b1 b:401.129(76) q:967.85(968)   bq:1043.62  B:0.065   <>:-2.08
# b2 b:6084.0(1149) q:21.57(22)   bq:1170.83  B:0.025   <>:-0.82
#
# ------------BUSD_TO_BNB
# b1 b:401.129(76) q:967.85(968)   bq:1043.62  B:0.065   <>:0.00
# b2 b:6084.0(1149) q:21.57(22)   bq:1170.83  B:0.025   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:401.129(76) q:967.85(968)   bq:1043.62  B:0.065   <>:0.00
# b2 b:6084.0(1149) q:21.57(22)   bq:1170.83  B:0.025   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1893 quantity: 5016
# b2 setOrder HARDBUSD origQty:5016 exQty:0
# b1 setOrder HARDBUSD origQty:5016 exQty:5016
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5412.113(1022) q:18.32(18)   bq:1040.66  B:0.065   <>:-2.96
# b2 b:1068.0(202) q:971.10(971)   bq:1172.84  B:0.025   <>:2.01
# sleep:  28.460858483781244
#
# --------------------------------------------------------------------------------
# шаг 12
#
# ------------BUY - SELL
# b1 b:5412.113(1022) q:18.32(18)   bq:1040.66  B:0.065   <>:0.00
# b2 b:1068.0(202) q:971.10(971)   bq:1172.84  B:0.025   <>:0.00
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1889   ask: 0.1893
# HARDBUSD . спрэд: 0.47   ping: 38   bid: 0.1889   ask: 0.1898
# HARDBUSD . спрэд: 0.26   ping: 46   bid: 0.1889   ask: 0.1894
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1889   ask: 0.1893
# HARDBUSD . спрэд: 0.26   ping: 32   bid: 0.1888   ask: 0.1893
# HARDBUSD . спрэд: 0.42   ping: 61   bid: 0.1889   ask: 0.1897
# HARDBUSD . спрэд: 0.21   ping: 62   bid: 0.1889   ask: 0.1893
# HARDBUSD . спрэд: 0.68   ping: 48   bid: 0.1889   ask: 0.1902
# b2 BUY  HARDBUSD price_dwn: 0.189 quantity: 5032
# bot1 try SELL  5032
# b2 setOrder HARDBUSD origQty:5032 exQty:0
# b1 setOrder HARDBUSD origQty:5032 exQty:5032
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b1 b:380.113(72) q:968.42(968)   bq:1040.18  B:0.065   <>:-0.48
# b2 b:6100.0(1152) q:20.05(20)   bq:1171.73  B:0.025   <>:-1.11
#
# ------------SELL - BUY
# b1 b:380.113(72) q:968.42(968)   bq:1040.18  B:0.065   <>:0.00
# b2 b:6100.0(1152) q:20.05(20)   bq:1171.73  B:0.025   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.189 quantity: 5021
# b2 setOrder HARDBUSD origQty:5021 exQty:0
# b1 setOrder HARDBUSD origQty:5021 exQty:5021
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5396.092(1019) q:19.45(19)   bq:1038.77  B:0.065   <>:-1.41
# b2 b:1079.0(204) q:969.02(969)   bq:1172.84  B:0.025   <>:1.11
# sleep:  21.694613691020283
#
# --------------------------------------------------------------------------------
# шаг 13
#
# ------------BUY - SELL
# b1 b:5396.092(1019) q:19.45(19)   bq:1038.77  B:0.065   <>:0.00
# b2 b:1079.0(204) q:969.02(969)   bq:1172.84  B:0.025   <>:0.00
# HARDBUSD . спрэд: 0.21   ping: 47   bid: 0.1889   ask: 0.1893
# HARDBUSD . спрэд: 0.26   ping: 33   bid: 0.1889   ask: 0.1894
# HARDBUSD . спрэд: 0.42   ping: 31   bid: 0.1889   ask: 0.1897
# HARDBUSD . спрэд: 0.37   ping: 48   bid: 0.1889   ask: 0.1896
# HARDBUSD . спрэд: 0.32   ping: 28   bid: 0.1889   ask: 0.1895
# HARDBUSD . спрэд: 0.47   ping: 32   bid: 0.1889   ask: 0.1898
# HARDBUSD . спрэд: 0.37   ping: 41   bid: 0.1889   ask: 0.1896
# HARDBUSD . спрэд: 0.47   ping: 38   bid: 0.1889   ask: 0.1898
# HARDBUSD . спрэд: 0.32   ping: 43   bid: 0.1889   ask: 0.1895
# HARDBUSD . спрэд: 0.37   ping: 46   bid: 0.1889   ask: 0.1896
# HARDBUSD . спрэд: 0.32   ping: 31   bid: 0.1889   ask: 0.1895
# HARDBUSD . спрэд: 0.47   ping: 64   bid: 0.1889   ask: 0.1898
# HARDBUSD . спрэд: 0.37   ping: 29   bid: 0.1889   ask: 0.1896
# HARDBUSD . спрэд: 0.42   ping: 28   bid: 0.1889   ask: 0.1897
# HARDBUSD . спрэд: 0.26   ping: 33   bid: 0.189   ask: 0.1895
# HARDBUSD . спрэд: 0.37   ping: 31   bid: 0.189   ask: 0.1897
# HARDBUSD . спрэд: 0.26   ping: 53   bid: 0.189   ask: 0.1895
# HARDBUSD . спрэд: 0.11   ping: 48   bid: 0.1891   ask: 0.1893
# HARDBUSD . спрэд: 0.21   ping: 27   bid: 0.1891   ask: 0.1895
# HARDBUSD . спрэд: 0.37   ping: 30   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.42   ping: 62   bid: 0.1893   ask: 0.1901
# HARDBUSD . спрэд: 0.32   ping: 62   bid: 0.1893   ask: 0.1899
# HARDBUSD . спрэд: 0.26   ping: 31   bid: 0.1893   ask: 0.1898
# HARDBUSD . спрэд: 0.42   ping: 76   bid: 0.1893   ask: 0.1901
# HARDBUSD . спрэд: 0.16   ping: 32   bid: 0.1893   ask: 0.1896
# HARDBUSD . спрэд: 0.53   ping: 33   bid: 0.1893   ask: 0.1903
# HARDBUSD . спрэд: 0.16   ping: 38   bid: 0.1893   ask: 0.1896
# HARDBUSD . спрэд: 0.37   ping: 47   bid: 0.1893   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 29   bid: 0.1892   ask: 0.1896
# HARDBUSD . спрэд: 0.16   ping: 31   bid: 0.1893   ask: 0.1896
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1893   ask: 0.1897
# HARDBUSD . спрэд: 0.68   ping: 54   bid: 0.1894   ask: 0.1907
# HARDBUSD . спрэд: 0.58   ping: 94   bid: 0.1894   ask: 0.1905
# b2 BUY  HARDBUSD price_dwn: 0.1895 quantity: 5022
# bot1 try SELL  5022
# b2 setOrder HARDBUSD origQty:5022 exQty:0
# b1 setOrder HARDBUSD origQty:5022 exQty:5022
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b1 b:374.092(71) q:970.17(970)   bq:1041.01  B:0.065   <>:2.24
# b2 b:6101.0(1156) q:17.35(17)   bq:1172.88  B:0.025   <>:0.04
#
# ------------BUSD_TO_BNB
# b1 b:374.092(71) q:970.17(970)   bq:1041.01  B:0.065   <>:0.00
# b2 b:6101.0(1156) q:17.35(17)   bq:1172.88  B:0.025   <>:0.00
# b1 BNB ok
# b2 BNB ok
#
# ------------SELL - BUY
# b1 b:374.092(71) q:970.17(970)   bq:1041.01  B:0.065   <>:0.00
# b2 b:6101.0(1156) q:17.35(17)   bq:1172.88  B:0.025   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1896 quantity: 5014
# b2 setOrder HARDBUSD origQty:5014 exQty:0
# b1 setOrder HARDBUSD origQty:5014 exQty:5014
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5383.078(1020) q:19.51(20)   bq:1039.6  B:0.065   <>:-1.41
# b2 b:1087.0(206) q:968.01(968)   bq:1173.99  B:0.025   <>:1.11
# sleep:  15.268314946262786
#
# --------------------------------------------------------------------------------
# шаг 14
#
# ------------BUY - SELL
# b1 b:5383.078(1020) q:19.51(20)   bq:1039.6  B:0.065   <>:0.00
# b2 b:1087.0(206) q:968.01(968)   bq:1173.99  B:0.025   <>:0.00
# HARDBUSD . спрэд: 0.16   ping: 63   bid: 0.1895   ask: 0.1898
# HARDBUSD . спрэд: 0.52   ping: 31   bid: 0.1895   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 73   bid: 0.1895   ask: 0.1898
# HARDBUSD . спрэд: 0.26   ping: 47   bid: 0.1895   ask: 0.19
# HARDBUSD . спрэд: 0.16   ping: 30   bid: 0.1895   ask: 0.1898
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1895   ask: 0.1899
# HARDBUSD . спрэд: 0.47   ping: 31   bid: 0.1896   ask: 0.1905
# HARDBUSD . спрэд: 0.42   ping: 33   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.47   ping: 48   bid: 0.1897   ask: 0.1906
# HARDBUSD . спрэд: 0.73   ping: 27   bid: 0.1891   ask: 0.1905
# b2 BUY  HARDBUSD price_dwn: 0.1892 quantity: 5001
# bot1 try SELL  5001
# b2 setOrder HARDBUSD origQty:5001 exQty:0
# b1 setOrder HARDBUSD origQty:5001 exQty:5001
# b1 Откуп SELL = FILLED
# buy_sell() True
#
# b2 oo0 закрыл остатки HARDBUSD origQty:5001 exQty:3945
# b1 b:382.078(72) q:964.86(965)   bq:1037.22  B:0.065   <>:-2.38
# b2 b:5032.0(953) q:221.61(222)   bq:1174.67  B:0.025   <>:0.68
#
# ------------SELL - BUY
# b1 b:382.078(72) q:964.86(965)   bq:1037.22  B:0.065   <>:0.00
# b2 b:5032.0(953) q:221.61(222)   bq:1174.67  B:0.025   <>:0.00
# b2 SELL  HARDBUSD price_up: 0.1898 quantity: 4926
# b2 setOrder HARDBUSD origQty:4926 exQty:0
# b1 setOrder HARDBUSD origQty:4926 exQty:4926
# b1 Откуп BUY = FILLED
# sell_buy() True
#
# b1 b:5303.152(1005) q:29.91(30)   bq:1034.85  B:0.065   <>:-2.37
# b2 b:106.0(20) q:1156.57(1157)   bq:1176.65  B:0.025   <>:1.98
# sleep:  11.364949020567234
#
# --------------------------------------------------------------------------------
# шаг 15
#
# ------------BUY - SELL
# b1 b:5303.152(1005) q:29.91(30)   bq:1035.38  B:0.065   <>:0.53
# b2 b:106.0(20) q:1156.57(1157)   bq:1176.66  B:0.025   <>:0.01
# HARDBUSD . спрэд: 0.21   ping: 64   bid: 0.1896   ask: 0.19
# HARDBUSD . спрэд: 0.16   ping: 29   bid: 0.1897   ask: 0.19
# HARDBUSD . спрэд: 0.21   ping: 31   bid: 0.1897   ask: 0.1901
# HARDBUSD . спрэд: 0.26   ping: 49   bid: 0.1897   ask: 0.1902
# HARDBUSD . спрэд: 0.21   ping: 46   bid: 0.1898   ask: 0.1902
# HARDBUSD . спрэд: 0.37   ping: 66   bid: 0.1895   ask: 0.1902
# HARDBUSD . спрэд: 0.26   ping: 60   bid: 0.1897   ask: 0.1902
# HARDBUSD . спрэд: 0.52   ping: 48   bid: 0.1897   ask: 0.1907
# HARDBUSD . спрэд: 0.47   ping: 61   bid: 0.1897   ask: 0.1906
# HARDBUSD . спрэд: 0.37   ping: 52   bid: 0.1899   ask: 0.1906
# HARDBUSD . спрэд: 0.31   ping: 59   bid: 0.1899   ask: 0.1905
# HARDBUSD . спрэд: 0.42   ping: 32   bid: 0.1899   ask: 0.1907
# HARDBUSD . спрэд: 0.31   ping: 48   bid: 0.1899   ask: 0.1905
# HARDBUSD . спрэд: 0.42   ping: 42   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.52   ping: 61   bid: 0.1897   ask: 0.1907
# HARDBUSD . спрэд: 0.42   ping: 52   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.37   ping: 47   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.52   ping: 43   bid: 0.1897   ask: 0.1907
# HARDBUSD . спрэд: 0.47   ping: 31   bid: 0.1897   ask: 0.1906
# HARDBUSD . спрэд: 0.42   ping: 76   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.37   ping: 67   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.42   ping: 38   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.52   ping: 32   bid: 0.1897   ask: 0.1907
# HARDBUSD . спрэд: 0.42   ping: 46   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.47   ping: 31   bid: 0.1897   ask: 0.1906
# HARDBUSD . спрэд: 0.16   ping: 76   bid: 0.1897   ask: 0.19
# HARDBUSD . спрэд: 0.32   ping: 36   bid: 0.1897   ask: 0.1903
# HARDBUSD . спрэд: 0.37   ping: 47   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.47   ping: 63   bid: 0.1897   ask: 0.1906
# HARDBUSD . спрэд: 0.21   ping: 45   bid: 0.1897   ask: 0.1901
# HARDBUSD . спрэд: 0.42   ping: 52   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.21   ping: 30   bid: 0.1897   ask: 0.1901
# HARDBUSD . спрэд: 0.11   ping: 47   bid: 0.1897   ask: 0.1899
# HARDBUSD . спрэд: 0.37   ping: 33   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.52   ping: 47   bid: 0.1897   ask: 0.1907
# HARDBUSD . спрэд: 0.42   ping: 46   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.37   ping: 47   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.42   ping: 46   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.52   ping: 45   bid: 0.1897   ask: 0.1907
# HARDBUSD . спрэд: 0.42   ping: 46   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.52   ping: 67   bid: 0.1897   ask: 0.1907
# HARDBUSD . спрэд: 0.42   ping: 63   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.16   ping: 80   bid: 0.1898   ask: 0.1901
# HARDBUSD . спрэд: 0.21   ping: 39   bid: 0.1897   ask: 0.1901
# HARDBUSD . спрэд: 0.16   ping: 43   bid: 0.1897   ask: 0.19
# HARDBUSD . спрэд: 0.42   ping: 63   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.37   ping: 78   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.42   ping: 56   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.52   ping: 79   bid: 0.1897   ask: 0.1907
# HARDBUSD . спрэд: 0.21   ping: 78   bid: 0.1897   ask: 0.1901
# HARDBUSD . спрэд: 0.16   ping: 30   bid: 0.1897   ask: 0.19
# HARDBUSD . спрэд: 0.37   ping: 77   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.42   ping: 68   bid: 0.1897   ask: 0.1905
# HARDBUSD . спрэд: 0.37   ping: 63   bid: 0.1897   ask: 0.1904
# HARDBUSD . спрэд: 0.26   ping: 60   bid: 0.1897   ask: 0.1902
# HARDBUSD . спрэд: 0.16   ping: 78   bid: 0.1897   ask: 0.19

# %% [markdown]
# # Балансы

# %%
#Балансы

get_new_Work_usd()


#
if bal['bot1']['quote_in_usd'] > Work_usd and bal['bot2']['base_in_usd'] > Work_usd :
  print('need SellBuy')

if bal['bot1']['base_in_usd'] > Work_usd and bal['bot2']['quote_in_usd'] > Work_usd :
  print('need BuySell')

if bal['bot1']['base_in_usd'] > Work_usd and bal['bot2']['base_in_usd'] > Work_usd :
  print('need sell base')

if bal['bot1']['quote_in_usd'] > Work_usd and bal['bot2']['quote_in_usd'] > Work_usd :
  print('need buy base')
# Out:
# b1 b:0.0(0) q:1253.17(1253)   bq:1253.16  B:0.0   <>:1253.16
# b2 b:0.0(0) q:1063.50(1063)   bq:1063.49  B:0.022   <>:1063.49
# New W_usd: 957.15
# need buy base

# %% [markdown]
# ## Начальная закупка

# %%
# Начальная закупка base на bot1   и quote на bot2
#get_new_Work_usd()
Work_usd  = 900 #

# bot1 Купить baseAsset из Work_usd
try :
  print(usd_to_base( bot1, Work_usd))
except :
  print('b1 не купили')  
# bot2 Купить quoteAsset из Work_usd
try:
  print(usd_to_quote(bot2, Work_usd))
except :
  print('b2 не купили')
# Out:
# b1  usd_to_base: HARDBUSD 900
# HARDBUSD origQty:4763 exQty:4763
# {'symbol': 'HARDBUSD', 'orderId': 97553079, 'orderListId': -1, 'clientOrderId': 'JAZLwnhH1R75QPzvtA0NwF', 'transactTime': 1675114095501, 'price': '0.00000000', 'origQty': '4763.00000000', 'executedQty': '4763.00000000', 'cummulativeQuoteQty': '898.91500000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1675114095501, 'fills': [{'price': '0.18840000', 'qty': '510.00000000', 'commission': '0.51000000', 'commissionAsset': 'HARD', 'tradeId': 4571841}, {'price': '0.18850000', 'qty': '852.00000000', 'commission': '0.85200000', 'commissionAsset': 'HARD', 'tradeId': 4571842}, {'price': '0.18870000', 'qty': '1649.00000000', 'commission': '1.64900000', 'commissionAsset': 'HARD', 'tradeId': 4571843}, {'price': '0.18890000', 'qty': '819.00000000', 'commission': '0.81900000', 'commissionAsset': 'HARD', 'tradeId': 4571844}, {'price': '0.18900000', 'qty': '767.00000000', 'commission': '0.76700000', 'commissionAsset': 'HARD', 'tradeId': 4571845}, {'price': '0.18910000', 'qty': '166.00000000', 'commission': '0.16600000', 'commissionAsset': 'HARD', 'tradeId': 4571846}], 'selfTradePreventionMode': 'NONE'}
# o NULL
# {'не перекидываем ', 'BUSDBUSD'}

# %% [markdown]
# ## распродажа монет

# %%
    # Перегоняем Quote и Base в USD
    bal = get_balances() 

    if bal['bot1']['baseAsset']  > bal['base_min']  : 
        a=0
        try : base_to_usd(bot1, bal['bot1']['baseAsset'])
        except : print('err bot1 base_to_usd')

    if bal['bot1']['quoteAsset'] > bal['quote_min'] : 
        a=0
        try : quote_to_usd(bot1, bal['bot1']['quoteAsset'])
        except : print('err bot1 quote_to_usd')


    if bal['bot2']['baseAsset']  > bal['base_min']  : 
        a=0
        try : base_to_usd(bot2, bal['bot2']['baseAsset'])   
        except : print('err bot2 base_to_usd')
    if bal['bot2']['quoteAsset'] > bal['quote_min'] : 
        a=0
        try : quote_to_usd(bot2, bal['bot2']['quoteAsset'])
        except : print('err bot2 quote_to_usd')
# Out:
# b1 b:203848.0(527) q:788.04(788)   bq:1315.39  B:0.056   <>:1315.39
# b2 b:3624.0(9) q:459.70(460)   bq:469.07  B:0.057   <>:469.07
# b1  base_to_usd: TROYBUSD 203848.0
# TROYBUSD origQty:203644 exQty:203644
# o NULL
# o NULL

# %%
f = open('client_report.txt','w')

f.write(str(client_report))

f.close()

# %%
cancel_orders(bot1)
cancel_orders(bot2)

# %% [markdown]
# ## Балансы > 0

# %%
# Balances > 0

print('bot1')
acc = bot1.account()['balances']
for i in range( len(acc) ):
  if float(acc[i]['free']) > 0 :
    print(acc[i])

print('bot2')
acc = bot2.account()['balances']
for i in range( len(acc) ):
  if float(acc[i]['free']) > 0 :
    print(acc[i])
# Out:
# bot1
# {'asset': 'BTC', 'free': '0.00000935', 'locked': '0.00000000'}
# {'asset': 'BNB', 'free': '0.05937970', 'locked': '0.00000000'}
# {'asset': 'DOCK', 'free': '50.76300000', 'locked': '0.00000000'}
# {'asset': 'FTM', 'free': '3104.60000000', 'locked': '0.00000000'}
# {'asset': 'BUSD', 'free': '5.01291695', 'locked': '0.00000000'}
# {'asset': 'RUB', 'free': '619.36900000', 'locked': '0.00000000'}
# {'asset': 'TROY', 'free': '204.00000000', 'locked': '0.00000000'}
# {'asset': 'WBTC', 'free': '0.00012543', 'locked': '0.00000000'}
# {'asset': 'OG', 'free': '0.20000000', 'locked': '0.00000000'}
# bot2
# {'asset': 'NEO', 'free': '0.00900000', 'locked': '0.00000000'}
# {'asset': 'BNB', 'free': '0.10236860', 'locked': '0.00000000'}
# {'asset': 'USDT', 'free': '1.11998869', 'locked': '0.00000000'}
# {'asset': 'BUSD', 'free': '10.01875603', 'locked': '0.00000000'}
# {'asset': 'RUB', 'free': '36948.36000000', 'locked': '0.00000000'}

# %% [markdown]
# ## createOrders

# %%
qty = 2000
#pair = base_usd
pair = 'ALGOUSDT'
#pair = 'BUSDUSDT'
#pair = 'ALICEBNB'

bot1.createOrder(
      symbol        = pair, 
      #quantity      = rounds( qty * 0.9995, sett[ pair ]['lot_precision'] ),
      quoteOrderQty = rounds( qty * 0.9995, sett[ pair ]['lot_precision'] ),
      recvWindow    = 5000, side = 'BUY', type  = 'MARKET'
      )

# %% [markdown]
# # START

# %%
from tkinter import *  # для построения окна

stop_stream = True
ws = Tk() # создается окно
ws.title('pyaudio')
def clicked():  
    global stop_stream
    stop_stream = True
btn = Button(ws, text="Stop", command=clicked)  
btn.grid(column=2, row=0)
