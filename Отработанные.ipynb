# %%
# 33$
#b1_API_KEY='vnYRxJNjBiZOfsCfnBwlQeTpOdm2qYGunrE3nB2aqeOwC6w00Smwu8famfnXvTRf'
#b1_API_SECRET='NLCnXRiHFmHsBRn3fCbmztLHgwTBv8xAvvzAW4U5OBRZ40ZNHEQT0Gqil2NcUh45'
# 32$
#b1_API_KEY='fdhJf0iGmzkPW2kmVB7llaq1RTsZtIoSyC532NSjrE6HQPWzRzT95AUlHcNTYBro'
#b1_API_SECRET='dnS3VXDDnquVbW5O3frW5UsWpZyXRDOY3P2W4fppzjKoKtgmLieRDXahrwCxCP6I' 

РАССЧИТАН

# %%
# 21
#Заблокированиы 12000$
#b1_API_KEY='palN3mfehY3ooMFcLHnDYT4AHFXB5DoANTBSZVCFNzR5oGU0NRMsejHPYKftsVTU'
#b1_API_SECRET='l3ZQ6dvm7iEO7LYzdj0PPoXU3KtSumZOQMwEV3fjzZH3VsS9p7sVY5YEc0ePmUFf'

РАССЧИТАН

# %%
# 22
# 10125 -> 712 пришло 4802
#b1_API_KEY='Mhk1Vhex5MuBWKCuBjrEwWpUKC5oR2waHGQJKKhXOIRmrWWx5UWy0sbekuGIjjDS'
#b1_API_SECRET='dfwrAQVjzsuXhVHDbfncE6dfEUYF1e4xth78XD0WVMipvHVijaACRJDacYZTrMor'

РАССЧИТАН

# %%
# 23
𝕱𝖎𝖓𝖌𝖊𝖗𝖒𝖆𝖘𝖙𝖊𝖗

Подключен к файлу
N
завершил 11.12.22

b1_start = 1798;

b1_API_KEY='0CVRQTEgqMbWxxQgprWoWOs3YSliEHCJkXER6QjaykhQ30rKMXCheoI8P2QT8qZb'
b1_API_SECRET='Fhp9ZoPMRxsN7mLm5LDDeuTwJn5moycjt6l498Iw0PwNZjje5OcW0tJwL5I5eDBA' 


было:  1798
ушло: 1244.34 $
сейчас: 553.66
к нам пришло: 289.03
Вытянули: 289.03/1244.34 = 23.23 % 

отдаем 65 % : 187.86949999999996 $
клиент получил 10 % от депозита
ОТКЛЮЧЕН-------------------------------------------------
докачал остатки
187+133 = 320 отдали
РАССЧИТАН

# %%
# 24
6.12.22
Подключен к файлу 
N

b1_API_KEY='Lcb2kM0mfjHbHQkqvDTjlvEkzio6AnW8Se5UvBf6hKQUTHwtGSq9i1d0M0rOiKaw'
b1_API_SECRET='WQsKjIU78B8z5x914DObzq0gFQtLvdnuVa1VERPrZf4xagoIQIr5rtxMY1AmmIf3'    

971$

Lcb2kM0mfjHbHQkqvDTjlvEkzio6AnW8Se5UvBf6hKQUTHwtGSq9i1d0M0rOiKaw
было:  972
ушло: 832.48 $
сейчас: 139.52
к нам пришло: 594.45
 594.45/832.48 = 71.41 % 

отдаем 50 % : 297.23 $
клиент получил 31 % от депозита
отдавали:  0 . Остались должны:  297
        
ОТКЛЮЧЕН-------------------------------------------------
РАССЧИТАН

# %%
# 25
08.12.22
Guliver

Подключен к файлу
A и A2 

14.12.22 Заблокирован

b1_API_KEY='THkUyXQDcW92bcS4ZVoIXCuY2Vc7uM0luAn3vphBOPbtbbUpbjDBzoltt8llj0hm'
b1_API_SECRET='6JiSdWb5oTazk5tlKim07yqM4U9eswnoWqSPcm4ipCmSDvbzKZ8qEFwiPQAghYaC'    

{'asset': 'USDT', 'free': '1531.65938631', 'locked': '0.00000000'}
{'asset': 'BUSD', 'free': '18166.95800330', 'locked': '0.00000000'}

отдали 1668 + 1766 + 1532


THkUyXQDcW92bcS4ZVoIXCuY2Vc7uM0luAn3vphBOPbtbbUpbjDBzoltt8llj0hm
было:  19700
ушло: 17747.23 $
сейчас: 1952.77
к нам пришло: 8996.57
 8996.57/17747.23 = 50.69 % 

отдаем 65 % : 5847.77 $
клиент получил 30 % от депозита
отдавали:  4966 . Остались должны:  882
        
ОТКЛЮЧЕН-------------------------------------------------
# !!!!РАССЧИТАТЬ ПОСЛЕ РАЗБЛОКИРОВКИ НАШЕГО СЧЕТА
РАССЧИТАН

# %%
# 26
09.12.22
Ivan Dunk
M
Завершил 23.12.22

b1_API_KEY='UHD2YfgL9ER8dMa2mi2RwZyunzmjCYiOOGvAaJRSfCcE7uZlR1E47MMMVpqJy6CJ'
b1_API_SECRET='Pf1hXxaUs0tvkHoCRy9nje2HCoQVBrGPfgIsx6VkDyVsqox8likidv23FQzb8eiy'    



UHD2YfgL9ER8dMa2mi2RwZyunzmjCYiOOGvAaJRSfCcE7uZlR1E47MMMVpqJy6CJ
было:  8689
ушло: 8412.22 $
сейчас: 276.78
к нам пришло: 3420.58
 3420.58/8412.22 = 40.66 % 

отдаем 50 % : 1710.29 $
клиент получил 20 % от депозита
отдавали:  1265 . Остались должны:  445

1710/3 = 570 Ивану

1015 отдаём

ОТКЛЮЧЕН-------------------------------------------------
РАССЧИТАН

# %%
# 27
11.12.2022 0:34
Guliver

Подключен к файлу
N

Завершил 13.12.22
Кто-то сливает всё в USDT
API заблокирован

b1_API_KEY='8cpotRZIiXw091wr8biXxnm8Vnk7wlCxya7p6ZIhetz9zqELg9YGeQKJKkYOVg9S'
b1_API_SECRET='n5sw3aOtYBP9vaLUhzdH8OrUS7TREb6PueByHmlZc5k8eHkZPcw257P8Z2zFgUju'    

8984$

8cpotRZIiXw091wr8biXxnm8Vnk7wlCxya7p6ZIhetz9zqELg9YGeQKJKkYOVg9S
было:  8984
ушло: 1392.98 $
сейчас: 7591.02
к нам пришло: 564.42
Вытянули: 564.42/1392.98 = 40.52 % 

отдаем 65 % : 366.87 $
клиент получил 4 % от депозита

# !!! Не рассчитали, Заказчик не требует

ОТКЛЮЧЕН-------------------------------------------------
РАССЧИТАН

# %%
# 28
11.12.2022
Guliver(не взяли)

Подключен к файлу
N

Завершил 23.12.22

b1_API_KEY='sDVGRmsKIUnVW6jUz4FXIMhJQYk3xftfgU92rBoHAzGMBSZQRMI5lEoo3znHsVnh'
b1_API_SECRET='zq3sXzxuvXeAiwRhgzlqdNQq5EAutaYWgM1R4xPSSdwPg5mLe8GU74IuoNQDFpbP'    

9046$

sDVGRmsKIUnVW6jUz4FXIMhJQYk3xftfgU92rBoHAzGMBSZQRMI5lEoo3znHsVnh
было:  9046
ушло: 8855.57 $
сейчас: 190.43
к нам пришло: 3907.54
 3907.54/8855.57 = 44.13 % 

отдаем 65 % : 2539.9 $
клиент получил 28 % от депозита
отдавали:  2540 . Остались должны:  0
        
ОТКЛЮЧЕН-------------------------------------------------
РАССЧИТАН

# %%
#29 
14.12.2022
IvanDunk(не взяли)

Подключен к файлу 

b1_API_KEY='zCjvsecFjafMYRbg4xnCGkWwny4cdub1BKriJjllaqMXxjOBccxmPup1TFXFSAiX'
b1_API_SECRET='vJ0xk02crNM8ND6dMahB2ZGIPm3N6XPJ4ldZEHi9ez6xsqhkhEn9NoRoJb3RlKzG'

2142$

Балансы смотреть можно. Торговать нельзя

# %%
#30
23.12.2022
Подключен к файлу
М

b1_API_KEY='ioCNuP9kxErl2zZZlHqTVFXUQR8uTxcn7gn6GuiqbMExmAcv7CyXT42QXOxDTZrq'
b1_API_SECRET='hrGsDJajAprbtTIdtHPizbq1e1Rno7bjr0mEs5v1ybnRfZjqsAGt1xHX76dDxIhF'

=1326
b1_start = 1326;   b2_start = 3000 - 1500; b2_ = 0; percent = 50 #M

ioCNuP9kxErl2zZZlHqTVFXUQR8uTxcn7gn6GuiqbMExmAcv7CyXT42QXOxDTZrq
было:  1326
ушло: 1217.26 $
сейчас: 108.74
к нам пришло: 893.64
 893.64/1217.26 = 73.41 % 

отдаем 70 % : 625 $

ОТКЛЮЧЕН-------------------------------------------------
РАССЧИТАН

# %%
#31
23.12.2022
Подключен к файлу
М

b1_API_KEY='HqUh0TJTZT82a527PDdXSVEJNZy3DobMRVKR04eCcFDb1ZpddPNSCkeRUyn8nuXD'
b1_API_SECRET='UyzQiWFDcyelX9eJzWSMuiK6WU1ymuHhGolcJA91Rbq2GNuvYWhVFtNdamybGiZn'

=4798


HqUh0TJTZT82a527PDdXSVEJNZy3DobMRVKR04eCcFDb1ZpddPNSCkeRUyn8nuXD
было:  4798
ушло: 4539.54 $
сейчас: 258.46
к нам пришло: 2537.46
 2537.46/4539.54 = 55.9 % 

отдаем 60 % : 1522.4 $
клиент получил 32 % от депозита
отдавали:  0 . Остались должны:  1522.4
        
ОТКЛЮЧЕН-------------------------------------------------
РАССЧИТАН

# %%
#32
24.12.2022

b1_API_KEY='1i89dqNIu1DLzYCmgd3f6r7GGmGMzYBZ2KaeeKY9UWN2sGzzWqF71VrSvdWbNww1'
b1_API_SECRET='7RNLaJmjpHKddRSGqEettmR3vzBntowRmyVzmmaY0GyPn8810ie5PldzuP1cETX2'
65%

=

Запрещена торговля

# %%
#33
26.12.22
Guliver
Подключен к файлу
N

b1_API_KEY='iKTHQZFB4uymzgUgX98wkO87M0haJyGjc3qJS0bA6ZOj3yCSeKlwfxhLJ0txOpP2'
b1_API_SECRET='QjaXnOsjnh437PsI68oThbkd4fyZljS3mgQO5Ejd7DiyP839sUU1YdNsM9Hd0TBr'

9113 BUSD

отдали 2022
65%

iKTHQZFB4uymzgUgX98wkO87M0haJyGjc3qJS0bA6ZOj3yCSeKlwfxhLJ0txOpP2
было:  9113
ушло: 9030.61 $
сейчас: 82.39
к нам пришло: 5519.56
 5519.56/9030.61 = 61.12 % 

отдаем 65 % : 3587.71 $
клиент получил 39 % от депозита
отдавали:  2978 . Остались должны:  610
        
ОТКЛЮЧИЛ
РАССЧИТАН

# %%
#34
26.12.22

b1_API_KEY='QJFCLuytNn4W8MTWZwZjNnpOkzeXrUSgQOZOvO0fPPu7hWlJASepcP6aM8Kcuqv1'
b1_API_SECRET='0TTM8RAvepTK44wnZkUSCdJUQ0ue2ZrKVdruVAMGZ9uipJFDtmZw74oDWtxGRrvD'
(London) (2k)
50%

QJFCLuytNn4W8MTWZwZjNnpOkzeXrUSgQOZOvO0fPPu7hWlJASepcP6aM8Kcuqv1
было:  2105
ушло: 1786.05 $
сейчас: 318.95
к нам пришло: 1319.71
 1319.71/1786.05 = 73.89 % 

отдаем 50 % : 659.86 $
клиент получил 31 % от депозита
отдавали:  655 . Остались должны:  5

        
        
        
26.12.22 Подключен к файлу M   

09.01.23 Подеключен к файлу K 
ОТКЛЮЧЕН

QJFCLuytNn4W8MTWZwZjNnpOkzeXrUSgQOZOvO0fPPu7hWlJASepcP6aM8Kcuqv1
было:  320
ушло: 264.92 $
сейчас: 55.08
к нам пришло: 192.92
 192.92/264.92 = 72.82 % 

отдаем 50 % : 96.46 $
клиент получил 30 % от депозита
отдавали:  0 . Остались должны:  96


нам 50 % : 96.5 $
на нашем счете: 543.92
    
    
РАССЧИТАН

# %%
#35
8.12.2022

b1_API_KEY='CWQKDeE0PFg8myFybbwlswHtUKVPCaz67yf7dMtoexyXeRfUx1mruVilbAV6UWTt'; N=35; percent=65
b1_API_SECRET='wHcxaLMJ7GaPxoD53Ak4CQbNjoSmQ89pHLSY45OOfBc2ksbRKmHo3UyFJW4Wi03v'

b1_API_KEY='7DMjs29QpZqLzlFojTG17WW32K5ZXkBB0p5nUhmn69Zl42plPlwQx4K3ZNpSjnHu'
b1_API_SECRET='mRY6SBVGoOQn0GV8jHjm3prWErZ9Eu7WgMx2ePEC7vgdVzgTRrCYz0mFTuA43BiB'
(MMM) (2k)
35%



CWQKDeE0PFg8myFybbwlswHtUKVPCaz67yf7dMtoexyXeRfUx1mruVilbAV6UWTt
было:  2075
ушло: 1473.54 $
сейчас: 601.46
к нам пришло: 929.31
 929.31/1473.54 = 63.07 % 

отдаем 65 % : 604.05 $
клиент получил 29 % от депозита
отдавали:  0 . Остались должны:  604


нам 35 % : 325.3 $
на нашем счете: 2129.31
    
    09.01.23
ОТКЛЮЧИЛ от В
Подключил на М

Замена АПИ

7DMjs29QpZqLzlFojTG17WW32K5ZXkBB0p5nUhmn69Zl42plPlwQx4K3ZNpSjnHu
было:  627
ушло: 451.37 $
сейчас: 175.63
к нам пришло: 298.47
 298.47/451.37 = 66.13 % 

отдаем 65 % : 194.01 $
клиент получил 31 % от депозита
отдавали:  0 . Остались должны:  194
        
ОТКЛЮЧИЛ
РАССЧИТАН

# %%
на M

b1_API_KEY='OFXJNieGPDR5dG0yHtNrtsLfFMjw50ljTmxmdmeEkznkHLJRJNtBXW11YliCKUrH'; N=36; percent=50
b1_API_SECRET='eiOjctoLXz89GPhfXMul7ZbRgqeyiwPrKlA3c8jUspIJPf2Ie4ugRzSBLAWkb543'  #2.01.2023

(Ivan_dunk) (5.1k)

50% for client,and 16 16 16


было:  5209

к нам пришло: 205.13
отдаем 50 % : 102.56 $
клиент получил 2 % от депозита
отдавали:  0 . Остались должны:  103
        
Заблочен АПИ

# %%
# состояние перелива до 17.01.23
import import_ipynb
F = 'K' # Выбрать букву счета и запустить

if F == 'A' :
    from A import b1_API_KEY, b1_API_SECRET, b2_API_KEY, b2_API_SECRET
    b1_start = 18200+1500; b2_start = 3936-1500   -1000-1766-1532  -2881-150-200 -500; otdali = 1766+1668+1532; percent = 65    #A
if F == 'B' :
    #b1_start= 2075; b2_start= 1200; otdali= 0; percent = 65
    from Bt import b1_API_KEY, b1_API_SECRET, b2_API_KEY, b2_API_SECRET
    b1_start= 276; b2_start= 2192-53 -610-604-194; otdali= 95; percent = 50 #    №26
if F == 'N' :
    #b1_start = 972;   b2_start = 1910 - 23-100  -500 -180; otdali = 0; percent = 50 
    from N import b1_API_KEY, b1_API_SECRET, b2_API_KEY, b2_API_SECRET
    b1_start = 9113;   b2_start = 1700 - 300 - 1822 -1000 -1200 -956 -24 -213 -200 - 472; otdali = 2022 +956; percent = 65 #N №33
if F == 'M' :
    #b1_start = 4798;   b2_start = 2393 - 2040; otdali = 0; percent = 50  №31
    #b1_start = 2105;   b2_start = 2890 - 2022-442-350; otdali = 442 +213; percent = 50  №34
    #b1_start = 5209;   b2_start = 1395; otdali = 0; percent = 50  №36
    from M import b1_API_KEY, b1_API_SECRET, b2_API_KEY, b2_API_SECRET
    b1_start = 627;   b2_start = 2079-200-95-66 -320; otdali = 194; percent = 65 # №33
if F == 'K' :
    from K import b1_API_KEY, b1_API_SECRET, b2_API_KEY, b2_API_SECRET
    #b1_start = 320;   b2_start = 351; otdali = 0; percent = 50    №34
    #b1_start = 520;   b2_start = 543; otdali = 133; percent = 50    №23
    b1_start = 1548;   b2_start = 918; otdali = 0; percent = 50  #  №37
    

print(' b1_K: ' + b1_API_KEY +'\n b1_S: ' + b1_API_SECRET + '\n\n b2_K: ' + b2_API_KEY + '\n b2_S: ' + b2_API_SECRET +'\n')
# %run fn.ipynb
report(b1_start, b2_start, otdali)

# %%
M
b1_API_KEY='Dnc2nQbRZbyA5UCHB7GR1jRQxXcg22a16PRLSF66w0vYPCi8QF8b7MtlZpmYrusR'; N=37; percent=65
b1_API_SECRET='g72bOnV5vHpoSdBF3OWOuJaA9A7pXOErj2RbzOu23LgaARASpAn0gfQARpzowx3b' #17.01.23

Dnc2nQbRZbyA5UCHB7GR1jRQxXcg22a16PRLSF66w0vYPCi8QF8b7MtlZpmYrusR
было:  1548
ушло: 1492.95 $
сейчас: 55.05
к нам пришло: 746.46
 746.46/1492.95 = 50.0 % 

отдаем 65 % : 485.2 $
клиент получил 31 % от депозита
отдавали:  0 . Остались должны:  485


нам 35 % : 261.3 $
на нашем счете: 1952.46
    
18.01.23
РАССЧИТАН

# %%
M
b1_API_KEY='5uyHfpQI9VP4YkTwOzRXbq54dfKfilknwfXZdxsK5JlayM2QCF4ub0VGKd5B0FwC'; N=38; percent=55
b1_API_SECRET='Vxu26bRAFaY1TCVQFL8pbBO3IjZLUsdIgD2qlkiCDJjdznLiNpVbqkBdLba6Zx9g' #20.01.23

5uyHfpQI9VP4YkTwOzRXbq54dfKfilknwfXZdxsK5JlayM2QCF4ub0VGKd5B0FwC
было:  1196
ушло: 1169.83 $
сейчас: 26.17
к нам пришло: 707.18
 707.18/1169.83 = 60.45 % 

отдаем 55 % : 388.95 $
клиент получил 33 % от депозита
отдавали:  290.7 . Остались должны:  98
        
РАССЧИТАЛИ

# %%
Мы выжидаем размер спрэда 0.5%. Но во время сделок могут пролезть и другие.
Сделка совершается на всю сумму депозита
За одну сделку перельется 0.5 счета
и будет улпачено 2 комиссии на покупку и на продажу
2*0.075% = 0.15%
Таким образом на комиссию уходит минимум 0.15/0.5 = 30%
Но рынок так устроен, что в сделки часто пролазят и эффективность на практике ещё ниже, чем 70%
Вот и получается от 40 до 70
